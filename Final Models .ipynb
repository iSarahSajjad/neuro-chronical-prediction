# %% [markdown]
# <a href="https://colab.research.google.com/github/iSarahSajjad/neuro-chronical-prediction/blob/Models/Final%20Models%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

main_file_path = '/content/drive/My Drive/ChronicAI/dataset/participants.tsv'

# Read the TSV file into a DataFrame using pandas
main_df = pd.read_csv(main_file_path, sep='\t')

base_dir = '/content/drive/My Drive/ChronicAI/dataset/'

# Create a list to store the combined data
combined_data = []

# Keep only the specified columns
main_df = main_df[['participant_id', 'age', 'origin', 'group']]

# Iterate through each row in the main DataFrame
for index, row in main_df.iterrows():
    participant_id = row['participant_id']

    # Define the path to the participant's directory
    participant_dir = os.path.join(base_dir, str(participant_id))

    # Check if the directory exists
    if os.path.exists(participant_dir):
        # Get a list of all TSV files in the participant's directory
        tsv_files = [f for f in os.listdir(participant_dir) if f.endswith('.tsv')]

        # Iterate through each TSV file
        for tsv_file in tsv_files:
            tsv_file_path = os.path.join(participant_dir, tsv_file)

            # Read the TSV file into a DataFrame
            participant_df = pd.read_csv(tsv_file_path, sep='\t')

            # Add the participant's ID to the DataFrame
            participant_df['participant_id'] = participant_id

            # Append the DataFrame to the combined data list
            combined_data.append(participant_df)

# Combine all the DataFrames in the list into a single DataFrame
combined_df = pd.concat(combined_data, ignore_index=True)

# Merge the combined DataFrame with the main DataFrame on participant_id
final_df = pd.merge(main_df, combined_df, on='participant_id', how='left')

# Display the first few rows of the final DataFrame
print(final_df.head())
# Out:
#   participant_id  age origin     group session_id  days_since_interview  \
# 0        sub-001   27      4  subacute  interview                   0.0
# 1        sub-001   27      4  subacute     visit1                   4.0
# 2        sub-001   27      4  subacute     visit2                  94.0
# 3        sub-001   27      4  subacute     visit3                   NaN
# 4        sub-001   27      4  subacute     visit4                 395.0
#
#   hours_sleep smoker limited_self_care/mobility bdi_total  ...  pdi_total  \
# 0      6 to 7      n                          y       1.0  ...          2
# 1      6 to 7      n                          n       NaN  ...         17
# 2         NaN    NaN                        NaN       NaN  ...         21
# 3           7      n                          n       7.0  ...          2
# 4         NaN    NaN                        NaN       7.0  ...          2
#
#    pdetect_pain_now  pdetect_strongest_4wks pdetect_pain_average_4wks  \
# 0                NaN                    NaN                       NaN
# 1                NaN                    NaN                       NaN
# 2                NaN                    NaN                       NaN
# 3                NaN                    NaN                       NaN
# 4                NaN                    NaN                       NaN
#
#   pdetect_pain_course pdetect_total changes_since_last_visit  \
# 0                 NaN           NaN                      NaN
# 1                 NaN           NaN         injury/more pain
# 2                 NaN           NaN      more/different pain
# 3                 NaN           NaN                     none
# 4                 NaN           NaN                      NaN
#
#   limited self care/mobility panas_total mpq_total
# 0                        NaN         NaN       NaN
# 1                        NaN         NaN       NaN
# 2                        NaN         NaN       NaN
# 3                        NaN         NaN       NaN
# 4                        NaN         NaN       NaN
#
# [5 rows x 52 columns]

# %%
output_csv_path = '/content/drive/My Drive/ChronicAI/dataset/final_df.csv'

# Ensure the directory for the output file exists
output_dir = os.path.dirname(output_csv_path)
os.makedirs(output_dir, exist_ok=True)

# Save the final DataFrame to a CSV file
final_df.to_csv(output_csv_path, index=False)

# %%
import os
import pandas as pd
import numpy as np
import shutil

# Path to the main directory containing MRI data
base_dir = '/content/drive/My Drive/ChronicAI/dataset/'

# Path to save the balanced dataset
balanced_dataset_dir = '/content/drive/My Drive/ChronicAI/dataset/OptimizedDataset/'

# Ensure the balanced dataset directory exists
if not os.path.exists(balanced_dataset_dir):
    os.makedirs(balanced_dataset_dir)

# Load the final DataFrame
final_df = pd.read_csv('/content/drive/My Drive/ChronicAI/dataset/final_df.csv')

# Create a DataFrame to hold the count of .nii files per participant and session
file_counts = []

for _, row in final_df.iterrows():
    participant_id = row['participant_id']
    session_id = row['session_id']
    group = row['group']

    # Define the source directory of MRI files
    source_dir = os.path.join(base_dir, str(participant_id), f'ses-{session_id}', 'anat')

    if os.path.exists(source_dir):
        # Count the number of .nii files
        nii_files = [f for f in os.listdir(source_dir) if f.endswith('.nii')]
        file_counts.append({'participant_id': participant_id, 'session_id': session_id, 'group': group, 'file_count': len(nii_files)})
    else:
        print(f"Warning: Source directory {source_dir} does not exist for participant {participant_id}, session {session_id}.")

# Convert to DataFrame
file_counts_df = pd.DataFrame(file_counts)

# Print the total count of MRIs for each group
print("Total count of MRIs for each group:")
print(file_counts_df.groupby('group')['file_count'].sum())

# Define the target number of MRIs for each group
group_counts = file_counts_df.groupby('group')['file_count'].sum()
min_count = group_counts.min()

# Sample equal number of MRI records from each group
balanced_df = file_counts_df.groupby('group').apply(lambda x: x.sample(min_count, random_state=42)).reset_index(drop=True)

# Print the total count of MRIs for each group after balancing
print("\nTotal count of MRIs for each group after balancing:")
print(balanced_df.groupby('group')['file_count'].sum())
# Out:
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-001/ses-interview/anat does not exist for participant sub-001, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-001/ses-visit3/anat does not exist for participant sub-001, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-002/ses-interview/anat does not exist for participant sub-002, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-003/ses-interview/anat does not exist for participant sub-003, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-003/ses-visit2/anat does not exist for participant sub-003, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-003/ses-visit5/anat does not exist for participant sub-003, session visit5.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-004/ses-interview/anat does not exist for participant sub-004, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-005/ses-interview/anat does not exist for participant sub-005, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-006/ses-interview/anat does not exist for participant sub-006, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-007/ses-interview/anat does not exist for participant sub-007, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-007/ses-visit4/anat does not exist for participant sub-007, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-008/ses-interview/anat does not exist for participant sub-008, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-009/ses-interview/anat does not exist for participant sub-009, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-009/ses-visit2/anat does not exist for participant sub-009, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-009/ses-visit4/anat does not exist for participant sub-009, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-interview/anat does not exist for participant sub-010, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit1/anat does not exist for participant sub-010, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit2/anat does not exist for participant sub-010, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit3/anat does not exist for participant sub-010, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit5/anat does not exist for participant sub-010, session visit5.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-011/ses-interview/anat does not exist for participant sub-011, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-011/ses-visit1/anat does not exist for participant sub-011, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-011/ses-visit4/anat does not exist for participant sub-011, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-011/ses-visit5/anat does not exist for participant sub-011, session visit5.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-012/ses-interview/anat does not exist for participant sub-012, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-013/ses-interview/anat does not exist for participant sub-013, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-014/ses-interview/anat does not exist for participant sub-014, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-014/ses-visit1/anat does not exist for participant sub-014, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-015/ses-interview/anat does not exist for participant sub-015, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-016/ses-interview/anat does not exist for participant sub-016, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-017/ses-interview/anat does not exist for participant sub-017, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-018/ses-interview/anat does not exist for participant sub-018, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-018/ses-visit3/anat does not exist for participant sub-018, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-019/ses-interview/anat does not exist for participant sub-019, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-019/ses-visit1/anat does not exist for participant sub-019, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-019/ses-visit4/anat does not exist for participant sub-019, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-020/ses-interview/anat does not exist for participant sub-020, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-interview/anat does not exist for participant sub-021, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-visit1/anat does not exist for participant sub-021, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-visit2/anat does not exist for participant sub-021, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-visit4/anat does not exist for participant sub-021, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-022/ses-interview/anat does not exist for participant sub-022, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-022/ses-visit2/anat does not exist for participant sub-022, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-023/ses-interview/anat does not exist for participant sub-023, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-023/ses-visit1/anat does not exist for participant sub-023, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-024/ses-interview/anat does not exist for participant sub-024, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-025/ses-interview/anat does not exist for participant sub-025, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-025/ses-visit1/anat does not exist for participant sub-025, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-026/ses-interview/anat does not exist for participant sub-026, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-027/ses-interview/anat does not exist for participant sub-027, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-027/ses-visit4/anat does not exist for participant sub-027, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-028/ses-interview/anat does not exist for participant sub-028, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-029/ses-interview/anat does not exist for participant sub-029, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-029/ses-visit4/anat does not exist for participant sub-029, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-030/ses-interview/anat does not exist for participant sub-030, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-030/ses-visit4/anat does not exist for participant sub-030, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-031/ses-interview/anat does not exist for participant sub-031, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-031/ses-visit3/anat does not exist for participant sub-031, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-032/ses-interview/anat does not exist for participant sub-032, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-033/ses-interview/anat does not exist for participant sub-033, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-034/ses-interview/anat does not exist for participant sub-034, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-034/ses-visit2/anat does not exist for participant sub-034, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-035/ses-interview/anat does not exist for participant sub-035, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-036/ses-interview/anat does not exist for participant sub-036, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-037/ses-interview/anat does not exist for participant sub-037, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-038/ses-interview/anat does not exist for participant sub-038, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-039/ses-interview/anat does not exist for participant sub-039, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-039/ses-visit2/anat does not exist for participant sub-039, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-040/ses-interview/anat does not exist for participant sub-040, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-040/ses-visit3/anat does not exist for participant sub-040, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-041/ses-interview/anat does not exist for participant sub-041, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-interview/anat does not exist for participant sub-042, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit1/anat does not exist for participant sub-042, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit2/anat does not exist for participant sub-042, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit4/anat does not exist for participant sub-042, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit5/anat does not exist for participant sub-042, session visit5.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-043/ses-interview/anat does not exist for participant sub-043, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-044/ses-interview/anat does not exist for participant sub-044, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-044/ses-visit1/anat does not exist for participant sub-044, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-044/ses-visit2/anat does not exist for participant sub-044, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-045/ses-interview/anat does not exist for participant sub-045, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-046/ses-interview/anat does not exist for participant sub-046, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-047/ses-interview/anat does not exist for participant sub-047, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-047/ses-visit2/anat does not exist for participant sub-047, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-048/ses-interview/anat does not exist for participant sub-048, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-048/ses-visit5/anat does not exist for participant sub-048, session visit5.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-049/ses-interview/anat does not exist for participant sub-049, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-049/ses-visit3/anat does not exist for participant sub-049, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-050/ses-interview/anat does not exist for participant sub-050, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-050/ses-visit3/anat does not exist for participant sub-050, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-051/ses-interview/anat does not exist for participant sub-051, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-052/ses-interview/anat does not exist for participant sub-052, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-052/ses-visit4/anat does not exist for participant sub-052, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-053/ses-interview/anat does not exist for participant sub-053, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-054/ses-interview/anat does not exist for participant sub-054, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-054/ses-visit2/anat does not exist for participant sub-054, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-055/ses-interview/anat does not exist for participant sub-055, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-056/ses-interview/anat does not exist for participant sub-056, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-056/ses-visit1/anat does not exist for participant sub-056, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-056/ses-visit4/anat does not exist for participant sub-056, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-057/ses-interview/anat does not exist for participant sub-057, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-057/ses-visit2/anat does not exist for participant sub-057, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-058/ses-interview/anat does not exist for participant sub-058, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-059/ses-interview/anat does not exist for participant sub-059, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-059/ses-visit1/anat does not exist for participant sub-059, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-059/ses-visit3/anat does not exist for participant sub-059, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-060/ses-interview/anat does not exist for participant sub-060, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-061/ses-interview/anat does not exist for participant sub-061, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-061/ses-visit1/anat does not exist for participant sub-061, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-061/ses-visit4/anat does not exist for participant sub-061, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-062/ses-interview/anat does not exist for participant sub-062, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-063/ses-interview/anat does not exist for participant sub-063, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-063/ses-visit3/anat does not exist for participant sub-063, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-063/ses-visit4/anat does not exist for participant sub-063, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-064/ses-interview/anat does not exist for participant sub-064, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-065/ses-interview/anat does not exist for participant sub-065, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-066/ses-interview/anat does not exist for participant sub-066, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-067/ses-interview/anat does not exist for participant sub-067, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-068/ses-interview/anat does not exist for participant sub-068, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-068/ses-visit4/anat does not exist for participant sub-068, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-069/ses-interview/anat does not exist for participant sub-069, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-070/ses-interview/anat does not exist for participant sub-070, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-070/ses-visit3/anat does not exist for participant sub-070, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-071/ses-interview/anat does not exist for participant sub-071, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-072/ses-interview/anat does not exist for participant sub-072, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-072/ses-visit4/anat does not exist for participant sub-072, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-073/ses-interview/anat does not exist for participant sub-073, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-073/ses-visit3/anat does not exist for participant sub-073, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-074/ses-interview/anat does not exist for participant sub-074, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-075/ses-interview/anat does not exist for participant sub-075, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-075/ses-visit1/anat does not exist for participant sub-075, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-076/ses-interview/anat does not exist for participant sub-076, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-077/ses-interview/anat does not exist for participant sub-077, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-078/ses-interview/anat does not exist for participant sub-078, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-078/ses-visit2/anat does not exist for participant sub-078, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-078/ses-visit4/anat does not exist for participant sub-078, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-079/ses-interview/anat does not exist for participant sub-079, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-080/ses-interview/anat does not exist for participant sub-080, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-081/ses-interview/anat does not exist for participant sub-081, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-082/ses-interview/anat does not exist for participant sub-082, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-083/ses-interview/anat does not exist for participant sub-083, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-084/ses-interview/anat does not exist for participant sub-084, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-085/ses-interview/anat does not exist for participant sub-085, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-085/ses-visit1/anat does not exist for participant sub-085, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-086/ses-interview/anat does not exist for participant sub-086, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-086/ses-visit2/anat does not exist for participant sub-086, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-087/ses-interview/anat does not exist for participant sub-087, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-088/ses-interview/anat does not exist for participant sub-088, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-089/ses-interview/anat does not exist for participant sub-089, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-090/ses-interview/anat does not exist for participant sub-090, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-091/ses-interview/anat does not exist for participant sub-091, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-interview/anat does not exist for participant sub-092, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit1/anat does not exist for participant sub-092, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit2/anat does not exist for participant sub-092, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit3/anat does not exist for participant sub-092, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit4/anat does not exist for participant sub-092, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-interview/anat does not exist for participant sub-093, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit1/anat does not exist for participant sub-093, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit2/anat does not exist for participant sub-093, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit3/anat does not exist for participant sub-093, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit4/anat does not exist for participant sub-093, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-interview/anat does not exist for participant sub-094, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit1/anat does not exist for participant sub-094, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit2/anat does not exist for participant sub-094, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit3/anat does not exist for participant sub-094, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit4/anat does not exist for participant sub-094, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-interview/anat does not exist for participant sub-095, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit1/anat does not exist for participant sub-095, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit2/anat does not exist for participant sub-095, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit3/anat does not exist for participant sub-095, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit4/anat does not exist for participant sub-095, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-096/ses-interview/anat does not exist for participant sub-096, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-096/ses-visit4/anat does not exist for participant sub-096, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-097/ses-interview/anat does not exist for participant sub-097, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-097/ses-visit3/anat does not exist for participant sub-097, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-098/ses-interview/anat does not exist for participant sub-098, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-interview/anat does not exist for participant sub-099, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-visit2/anat does not exist for participant sub-099, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-visit3/anat does not exist for participant sub-099, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-visit4/anat does not exist for participant sub-099, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-100/ses-interview/anat does not exist for participant sub-100, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-101/ses-interview/anat does not exist for participant sub-101, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-102/ses-interview/anat does not exist for participant sub-102, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-103/ses-interview/anat does not exist for participant sub-103, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-interview/anat does not exist for participant sub-104, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-visit2/anat does not exist for participant sub-104, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-visit3/anat does not exist for participant sub-104, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-visit4/anat does not exist for participant sub-104, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-105/ses-interview/anat does not exist for participant sub-105, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-106/ses-interview/anat does not exist for participant sub-106, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-107/ses-interview/anat does not exist for participant sub-107, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-108/ses-interview/anat does not exist for participant sub-108, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-109/ses-interview/anat does not exist for participant sub-109, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-110/ses-interview/anat does not exist for participant sub-110, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-110/ses-visit3/anat does not exist for participant sub-110, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-110/ses-visit4/anat does not exist for participant sub-110, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-111/ses-interview/anat does not exist for participant sub-111, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-112/ses-interview/anat does not exist for participant sub-112, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-113/ses-interview/anat does not exist for participant sub-113, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-113/ses-visit3/anat does not exist for participant sub-113, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-114/ses-interview/anat does not exist for participant sub-114, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-115/ses-interview/anat does not exist for participant sub-115, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-115/ses-visit2/anat does not exist for participant sub-115, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-116/ses-interview/anat does not exist for participant sub-116, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-117/ses-interview/anat does not exist for participant sub-117, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-117/ses-visit4/anat does not exist for participant sub-117, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-118/ses-interview/anat does not exist for participant sub-118, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-119/ses-interview/anat does not exist for participant sub-119, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-120/ses-interview/anat does not exist for participant sub-120, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-121/ses-interview/anat does not exist for participant sub-121, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-121/ses-visit4/anat does not exist for participant sub-121, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-interview/anat does not exist for participant sub-122, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit1/anat does not exist for participant sub-122, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit2/anat does not exist for participant sub-122, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit3/anat does not exist for participant sub-122, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit4/anat does not exist for participant sub-122, session visit4.
# Total count of MRIs for each group:
# group
# chronic      87
# healthy      80
# subacute    267
# Name: file_count, dtype: int64
#
# Total count of MRIs for each group after balancing:
# group
# chronic     80
# healthy     80
# subacute    80
# Name: file_count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Print the total count of MRIs for each group
print("Total count of MRIs for each group:")
total_counts = file_counts_df.groupby('group')['file_count'].sum()
print(total_counts)

# Plot the total count of MRIs for each group
plt.figure(figsize=(10, 6))
total_counts.plot(kind='bar', color=['blue', 'green', 'red'])
plt.title('Total Count of MRIs for Each Group')
plt.xlabel('Group')
plt.ylabel('Number of MRIs')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig('/content/drive/My Drive/ChronicAI/dataset/mri_counts_by_group.png')
plt.show()
# Out:
# Total count of MRIs for each group:
# group
# chronic      87
# healthy      80
# subacute    267
# Name: file_count, dtype: int64

# %%
import os
import pandas as pd
import numpy as np
import shutil
import nibabel as nib
from skimage import filters
from skimage.transform import resize
from skimage.exposure import equalize_hist
from skimage.restoration import denoise_bilateral

# Paths
base_dir = '/content/drive/My Drive/ChronicAI/dataset/'
balanced_dataset_dir = '/content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/'

# Ensure the balanced dataset directory exists
if not os.path.exists(balanced_dataset_dir):
    os.makedirs(balanced_dataset_dir)

# Load the final DataFrame
final_df = pd.read_csv('/content/drive/My Drive/ChronicAI/dataset/final_df.csv')

# Create a DataFrame to hold the count of .nii files per participant and session
file_counts = []

for _, row in final_df.iterrows():
    participant_id = row['participant_id']
    session_id = row['session_id']
    group = row['group']

    # Define the source directory of MRI files
    source_dir = os.path.join(base_dir, str(participant_id), f'ses-{session_id}', 'anat')

    if os.path.exists(source_dir):
        # Count the number of .nii files
        nii_files = [f for f in os.listdir(source_dir) if f.endswith('.nii')]
        file_counts.append({'participant_id': participant_id, 'session_id': session_id, 'group': group, 'file_count': len(nii_files)})
    else:
        print(f"Warning: Source directory {source_dir} does not exist for participant {participant_id}, session {session_id}.")

# Convert to DataFrame
file_counts_df = pd.DataFrame(file_counts)

# Calculate the maximum count of MRIs for any group
max_count = file_counts_df['file_count'].max()

# Print the maximum count
print(f"Maximum count of MRIs for any group: {max_count}")

# Create a DataFrame to hold the balanced dataset
balanced_df = final_df.copy()

# Create a directory for each group within the balanced dataset
for group in balanced_df['group'].unique():
    group_dir = os.path.join(balanced_dataset_dir, group)
    if not os.path.exists(group_dir):
        os.makedirs(group_dir)

# Process and augment MRI files
for _, row in balanced_df.iterrows():
    participant_id = row['participant_id']
    session_id = row['session_id']
    group = row['group']

    # Define the source directory of MRI files
    source_dir = os.path.join(base_dir, str(participant_id), f'ses-{session_id}', 'anat')

    if os.path.exists(source_dir):
        # Define the destination directory
        dest_dir = os.path.join(balanced_dataset_dir, group)
        print(f"Processing directory: {dest_dir}")

        # Process each .nii file
        for file_name in os.listdir(source_dir):
            if file_name.endswith('.nii'):
                source_file_path = os.path.join(source_dir, file_name)

                # Load the MRI file as a 3D volume
                mri_image_nii = nib.load(source_file_path)
                mri_image = mri_image_nii.get_fdata()

                # Normalize the image
                mri_image = (mri_image - np.min(mri_image)) / (np.max(mri_image) - np.min(mri_image))

                # Smoothen the MRI image
                mri_image = filters.gaussian(mri_image, sigma=1)

                # Apply histogram equalization for contrast enhancement
                mri_image = equalize_hist(mri_image)

                # Resize to a fixed size if needed
                target_shape = (128, 128, 128)  # Adjust as necessary
                mri_image_resized = resize(mri_image, target_shape, mode='reflect')

                # Save processed image (overwrite the original file if needed)
                destination_file_path = os.path.join(dest_dir, file_name)
                nib.save(nib.Nifti1Image(mri_image_resized, mri_image_nii.affine), destination_file_path)

                # Print the shape of the saved MRI file to verify 3D
                print(f"Processed and saved {destination_file_path} with shape: {mri_image_resized.shape}")

print(f"Balanced dataset saved to {balanced_dataset_dir} with maximum count of {max_count} samples per group.")
# Out:
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-001/ses-interview/anat does not exist for participant sub-001, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-001/ses-visit3/anat does not exist for participant sub-001, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-002/ses-interview/anat does not exist for participant sub-002, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-003/ses-interview/anat does not exist for participant sub-003, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-003/ses-visit2/anat does not exist for participant sub-003, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-003/ses-visit5/anat does not exist for participant sub-003, session visit5.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-004/ses-interview/anat does not exist for participant sub-004, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-005/ses-interview/anat does not exist for participant sub-005, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-006/ses-interview/anat does not exist for participant sub-006, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-007/ses-interview/anat does not exist for participant sub-007, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-007/ses-visit4/anat does not exist for participant sub-007, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-008/ses-interview/anat does not exist for participant sub-008, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-009/ses-interview/anat does not exist for participant sub-009, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-009/ses-visit2/anat does not exist for participant sub-009, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-009/ses-visit4/anat does not exist for participant sub-009, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-interview/anat does not exist for participant sub-010, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit1/anat does not exist for participant sub-010, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit2/anat does not exist for participant sub-010, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit3/anat does not exist for participant sub-010, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit5/anat does not exist for participant sub-010, session visit5.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-011/ses-interview/anat does not exist for participant sub-011, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-011/ses-visit1/anat does not exist for participant sub-011, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-011/ses-visit4/anat does not exist for participant sub-011, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-011/ses-visit5/anat does not exist for participant sub-011, session visit5.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-012/ses-interview/anat does not exist for participant sub-012, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-013/ses-interview/anat does not exist for participant sub-013, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-014/ses-interview/anat does not exist for participant sub-014, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-014/ses-visit1/anat does not exist for participant sub-014, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-015/ses-interview/anat does not exist for participant sub-015, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-016/ses-interview/anat does not exist for participant sub-016, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-017/ses-interview/anat does not exist for participant sub-017, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-018/ses-interview/anat does not exist for participant sub-018, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-018/ses-visit3/anat does not exist for participant sub-018, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-019/ses-interview/anat does not exist for participant sub-019, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-019/ses-visit1/anat does not exist for participant sub-019, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-019/ses-visit4/anat does not exist for participant sub-019, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-020/ses-interview/anat does not exist for participant sub-020, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-interview/anat does not exist for participant sub-021, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-visit1/anat does not exist for participant sub-021, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-visit2/anat does not exist for participant sub-021, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-visit4/anat does not exist for participant sub-021, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-022/ses-interview/anat does not exist for participant sub-022, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-022/ses-visit2/anat does not exist for participant sub-022, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-023/ses-interview/anat does not exist for participant sub-023, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-023/ses-visit1/anat does not exist for participant sub-023, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-024/ses-interview/anat does not exist for participant sub-024, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-025/ses-interview/anat does not exist for participant sub-025, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-025/ses-visit1/anat does not exist for participant sub-025, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-026/ses-interview/anat does not exist for participant sub-026, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-027/ses-interview/anat does not exist for participant sub-027, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-027/ses-visit4/anat does not exist for participant sub-027, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-028/ses-interview/anat does not exist for participant sub-028, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-029/ses-interview/anat does not exist for participant sub-029, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-029/ses-visit4/anat does not exist for participant sub-029, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-030/ses-interview/anat does not exist for participant sub-030, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-030/ses-visit4/anat does not exist for participant sub-030, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-031/ses-interview/anat does not exist for participant sub-031, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-031/ses-visit3/anat does not exist for participant sub-031, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-032/ses-interview/anat does not exist for participant sub-032, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-033/ses-interview/anat does not exist for participant sub-033, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-034/ses-interview/anat does not exist for participant sub-034, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-034/ses-visit2/anat does not exist for participant sub-034, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-035/ses-interview/anat does not exist for participant sub-035, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-036/ses-interview/anat does not exist for participant sub-036, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-037/ses-interview/anat does not exist for participant sub-037, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-038/ses-interview/anat does not exist for participant sub-038, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-039/ses-interview/anat does not exist for participant sub-039, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-039/ses-visit2/anat does not exist for participant sub-039, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-040/ses-interview/anat does not exist for participant sub-040, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-040/ses-visit3/anat does not exist for participant sub-040, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-041/ses-interview/anat does not exist for participant sub-041, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-interview/anat does not exist for participant sub-042, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit1/anat does not exist for participant sub-042, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit2/anat does not exist for participant sub-042, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit4/anat does not exist for participant sub-042, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit5/anat does not exist for participant sub-042, session visit5.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-043/ses-interview/anat does not exist for participant sub-043, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-044/ses-interview/anat does not exist for participant sub-044, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-044/ses-visit1/anat does not exist for participant sub-044, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-044/ses-visit2/anat does not exist for participant sub-044, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-045/ses-interview/anat does not exist for participant sub-045, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-046/ses-interview/anat does not exist for participant sub-046, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-047/ses-interview/anat does not exist for participant sub-047, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-047/ses-visit2/anat does not exist for participant sub-047, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-048/ses-interview/anat does not exist for participant sub-048, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-048/ses-visit5/anat does not exist for participant sub-048, session visit5.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-049/ses-interview/anat does not exist for participant sub-049, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-049/ses-visit3/anat does not exist for participant sub-049, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-050/ses-interview/anat does not exist for participant sub-050, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-050/ses-visit3/anat does not exist for participant sub-050, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-051/ses-interview/anat does not exist for participant sub-051, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-052/ses-interview/anat does not exist for participant sub-052, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-052/ses-visit4/anat does not exist for participant sub-052, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-053/ses-interview/anat does not exist for participant sub-053, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-054/ses-interview/anat does not exist for participant sub-054, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-054/ses-visit2/anat does not exist for participant sub-054, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-055/ses-interview/anat does not exist for participant sub-055, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-056/ses-interview/anat does not exist for participant sub-056, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-056/ses-visit1/anat does not exist for participant sub-056, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-056/ses-visit4/anat does not exist for participant sub-056, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-057/ses-interview/anat does not exist for participant sub-057, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-057/ses-visit2/anat does not exist for participant sub-057, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-058/ses-interview/anat does not exist for participant sub-058, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-059/ses-interview/anat does not exist for participant sub-059, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-059/ses-visit1/anat does not exist for participant sub-059, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-059/ses-visit3/anat does not exist for participant sub-059, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-060/ses-interview/anat does not exist for participant sub-060, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-061/ses-interview/anat does not exist for participant sub-061, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-061/ses-visit1/anat does not exist for participant sub-061, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-061/ses-visit4/anat does not exist for participant sub-061, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-062/ses-interview/anat does not exist for participant sub-062, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-063/ses-interview/anat does not exist for participant sub-063, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-063/ses-visit3/anat does not exist for participant sub-063, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-063/ses-visit4/anat does not exist for participant sub-063, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-064/ses-interview/anat does not exist for participant sub-064, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-065/ses-interview/anat does not exist for participant sub-065, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-066/ses-interview/anat does not exist for participant sub-066, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-067/ses-interview/anat does not exist for participant sub-067, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-068/ses-interview/anat does not exist for participant sub-068, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-068/ses-visit4/anat does not exist for participant sub-068, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-069/ses-interview/anat does not exist for participant sub-069, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-070/ses-interview/anat does not exist for participant sub-070, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-070/ses-visit3/anat does not exist for participant sub-070, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-071/ses-interview/anat does not exist for participant sub-071, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-072/ses-interview/anat does not exist for participant sub-072, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-072/ses-visit4/anat does not exist for participant sub-072, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-073/ses-interview/anat does not exist for participant sub-073, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-073/ses-visit3/anat does not exist for participant sub-073, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-074/ses-interview/anat does not exist for participant sub-074, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-075/ses-interview/anat does not exist for participant sub-075, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-075/ses-visit1/anat does not exist for participant sub-075, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-076/ses-interview/anat does not exist for participant sub-076, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-077/ses-interview/anat does not exist for participant sub-077, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-078/ses-interview/anat does not exist for participant sub-078, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-078/ses-visit2/anat does not exist for participant sub-078, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-078/ses-visit4/anat does not exist for participant sub-078, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-079/ses-interview/anat does not exist for participant sub-079, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-080/ses-interview/anat does not exist for participant sub-080, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-081/ses-interview/anat does not exist for participant sub-081, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-082/ses-interview/anat does not exist for participant sub-082, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-083/ses-interview/anat does not exist for participant sub-083, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-084/ses-interview/anat does not exist for participant sub-084, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-085/ses-interview/anat does not exist for participant sub-085, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-085/ses-visit1/anat does not exist for participant sub-085, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-086/ses-interview/anat does not exist for participant sub-086, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-086/ses-visit2/anat does not exist for participant sub-086, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-087/ses-interview/anat does not exist for participant sub-087, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-088/ses-interview/anat does not exist for participant sub-088, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-089/ses-interview/anat does not exist for participant sub-089, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-090/ses-interview/anat does not exist for participant sub-090, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-091/ses-interview/anat does not exist for participant sub-091, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-interview/anat does not exist for participant sub-092, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit1/anat does not exist for participant sub-092, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit2/anat does not exist for participant sub-092, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit3/anat does not exist for participant sub-092, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit4/anat does not exist for participant sub-092, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-interview/anat does not exist for participant sub-093, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit1/anat does not exist for participant sub-093, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit2/anat does not exist for participant sub-093, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit3/anat does not exist for participant sub-093, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit4/anat does not exist for participant sub-093, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-interview/anat does not exist for participant sub-094, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit1/anat does not exist for participant sub-094, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit2/anat does not exist for participant sub-094, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit3/anat does not exist for participant sub-094, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit4/anat does not exist for participant sub-094, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-interview/anat does not exist for participant sub-095, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit1/anat does not exist for participant sub-095, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit2/anat does not exist for participant sub-095, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit3/anat does not exist for participant sub-095, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit4/anat does not exist for participant sub-095, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-096/ses-interview/anat does not exist for participant sub-096, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-096/ses-visit4/anat does not exist for participant sub-096, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-097/ses-interview/anat does not exist for participant sub-097, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-097/ses-visit3/anat does not exist for participant sub-097, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-098/ses-interview/anat does not exist for participant sub-098, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-interview/anat does not exist for participant sub-099, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-visit2/anat does not exist for participant sub-099, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-visit3/anat does not exist for participant sub-099, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-visit4/anat does not exist for participant sub-099, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-100/ses-interview/anat does not exist for participant sub-100, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-101/ses-interview/anat does not exist for participant sub-101, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-102/ses-interview/anat does not exist for participant sub-102, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-103/ses-interview/anat does not exist for participant sub-103, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-interview/anat does not exist for participant sub-104, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-visit2/anat does not exist for participant sub-104, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-visit3/anat does not exist for participant sub-104, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-visit4/anat does not exist for participant sub-104, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-105/ses-interview/anat does not exist for participant sub-105, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-106/ses-interview/anat does not exist for participant sub-106, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-107/ses-interview/anat does not exist for participant sub-107, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-108/ses-interview/anat does not exist for participant sub-108, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-109/ses-interview/anat does not exist for participant sub-109, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-110/ses-interview/anat does not exist for participant sub-110, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-110/ses-visit3/anat does not exist for participant sub-110, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-110/ses-visit4/anat does not exist for participant sub-110, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-111/ses-interview/anat does not exist for participant sub-111, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-112/ses-interview/anat does not exist for participant sub-112, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-113/ses-interview/anat does not exist for participant sub-113, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-113/ses-visit3/anat does not exist for participant sub-113, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-114/ses-interview/anat does not exist for participant sub-114, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-115/ses-interview/anat does not exist for participant sub-115, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-115/ses-visit2/anat does not exist for participant sub-115, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-116/ses-interview/anat does not exist for participant sub-116, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-117/ses-interview/anat does not exist for participant sub-117, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-117/ses-visit4/anat does not exist for participant sub-117, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-118/ses-interview/anat does not exist for participant sub-118, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-119/ses-interview/anat does not exist for participant sub-119, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-120/ses-interview/anat does not exist for participant sub-120, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-121/ses-interview/anat does not exist for participant sub-121, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-121/ses-visit4/anat does not exist for participant sub-121, session visit4.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-interview/anat does not exist for participant sub-122, session interview.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit1/anat does not exist for participant sub-122, session visit1.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit2/anat does not exist for participant sub-122, session visit2.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit3/anat does not exist for participant sub-122, session visit3.
# Warning: Source directory /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit4/anat does not exist for participant sub-122, session visit4.
# Maximum count of MRIs for any group: 1
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-001_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-001_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-001_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-001_ses-visit5_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-002_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-002_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-002_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-002_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-003_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-003_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-003_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-004_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-004_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-004_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-004_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-005_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-005_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-005_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-005_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-006_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-006_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-006_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-006_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-006_ses-visit5_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-007_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-007_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-007_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-008_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-008_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-008_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-008_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-008_ses-visit5_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-009_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-009_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-009_ses-visit5_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-010_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-011_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-011_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-012_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-012_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-012_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-012_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-012_ses-visit5_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-013_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-013_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-013_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-013_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-013_ses-visit5_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-014_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-014_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-014_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-014_ses-visit5_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-015_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-015_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-015_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-015_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-016_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-016_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-016_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-016_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-016_ses-visit5_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-017_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/subacute/sub-017_ses-visit2_T1w.nii with shape: (128, 128, 128)
# ...
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-103_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-103_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-103_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-104_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-105_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-105_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-105_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-105_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-106_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-106_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-106_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-106_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-107_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-107_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-107_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-107_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-108_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-108_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-108_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-108_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-109_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-109_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-109_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-109_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-110_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-110_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-111_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-111_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-111_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-111_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-112_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-112_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-112_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-112_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-113_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-113_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-113_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-114_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-114_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-114_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-114_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-115_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-115_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-115_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-116_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-116_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-116_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-116_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-117_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-117_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-117_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-118_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-118_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-118_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-118_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-119_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-119_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-119_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-119_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-120_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-120_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-120_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-120_ses-visit4_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-121_ses-visit1_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-121_ses-visit2_T1w.nii with shape: (128, 128, 128)
# Processing directory: /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic
# Processed and saved /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/chronic/sub-121_ses-visit3_T1w.nii with shape: (128, 128, 128)
# Balanced dataset saved to /content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/ with maximum count of 1 samples per group.

# %%
# Count and print the number of .nii files in each directory
for group in balanced_df['group'].unique():
    group_dir = os.path.join(balanced_dataset_dir, group)
    file_count = len([f for f in os.listdir(group_dir) if f.endswith('.nii')])
    print(f"Total count of .nii files in '{group}' directory: {file_count}")
# Out:
# Total count of .nii files in 'subacute' directory: 267
# Total count of .nii files in 'healthy' directory: 80
# Total count of .nii files in 'chronic' directory: 87

# %%
import os
import shutil
import numpy as np

# Paths
base_dir = '/content/drive/My Drive/ChronicAI/dataset/OptimizedBalanceData/'
output_base_dir = '/content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/'

# Define train, test, and validation split sizes
val_size = 8
test_size = 16
train_size = 56

# Create the output directories if they don't exist
for group in ['healthy', 'chronic', 'subacute']:
    for split in ['train', 'test', 'val']:
        dir_path = os.path.join(output_base_dir, group, split)
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)

# Process each group
for group in ['healthy', 'chronic', 'subacute']:
    group_dir = os.path.join(base_dir, group)
    files = [f for f in os.listdir(group_dir) if f.endswith('.nii')]
    np.random.shuffle(files)  # Shuffle the files for randomness

    # Determine file splits
    val_files = files[:val_size]
    test_files = files[val_size:val_size + test_size]
    train_files = files[val_size + test_size:val_size + test_size + train_size]

    # Define destination directories
    val_dir = os.path.join(output_base_dir, group, 'val')
    test_dir = os.path.join(output_base_dir, group, 'test')
    train_dir = os.path.join(output_base_dir, group, 'train')

    # Copy validation files
    for file in val_files:
        src_file_path = os.path.join(group_dir, file)
        dest_file_path = os.path.join(val_dir, f"{group}_{file}")
        shutil.copy(src_file_path, dest_file_path)
        print(f"Copied {file} to {val_dir}")

    # Copy test files
    for file in test_files:
        src_file_path = os.path.join(group_dir, file)
        dest_file_path = os.path.join(test_dir, f"{group}_{file}")
        shutil.copy(src_file_path, dest_file_path)
        print(f"Copied {file} to {test_dir}")

    # Copy training files (only for subacute to maintain balance)
    if group == 'subacute':
        train_files = files[:train_size]
    else:
        train_files = files[val_size + test_size:val_size + test_size + train_size]

    for file in train_files:
        src_file_path = os.path.join(group_dir, file)
        dest_file_path = os.path.join(train_dir, f"{group}_{file}")
        shutil.copy(src_file_path, dest_file_path)
        print(f"Copied {file} to {train_dir}")

print("Data splitting complete.")
# Out:
# Copied sub-079_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/val
# Copied sub-072_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/val
# Copied sub-077_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/val
# Copied sub-090_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/val
# Copied sub-074_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/val
# Copied sub-075_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/val
# Copied sub-096_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/val
# Copied sub-075_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/val
# Copied sub-075_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-082_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-080_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-084_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-071_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-084_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-088_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-080_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-082_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-074_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-080_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-082_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-079_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-072_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-091_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-081_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Copied sub-088_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-074_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-080_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-090_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-071_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-071_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-076_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-089_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-081_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-090_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-089_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-073_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-085_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-087_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-088_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-072_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-083_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-078_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-082_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-071_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-087_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-089_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-086_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-079_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-083_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-088_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-096_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-076_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-073_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-076_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-091_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-077_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-086_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-091_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-077_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-090_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-087_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-076_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-073_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-078_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-087_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-091_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-085_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-084_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-089_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-083_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-084_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-083_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-086_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-077_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-074_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-096_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-079_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-085_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-081_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-081_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Copied sub-116_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/val
# Copied sub-119_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/val
# Copied sub-101_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/val
# Copied sub-120_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/val
# Copied sub-111_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/val
# Copied sub-114_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/val
# Copied sub-102_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/val
# Copied sub-112_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/val
# Copied sub-097_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-114_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-098_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-098_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-106_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-116_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-100_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-119_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-102_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-106_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-118_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-103_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-097_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-119_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-105_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-104_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Copied sub-109_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-105_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-111_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-108_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-102_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-110_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-108_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-121_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-114_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-098_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-107_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-116_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-118_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-110_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-098_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-103_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-101_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-112_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-109_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-120_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-108_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-112_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-117_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-106_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-116_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-102_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-115_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-105_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-100_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-119_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-106_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-097_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-101_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-112_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-115_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-103_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-117_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-113_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-117_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-120_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-115_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-113_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-107_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-103_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-118_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-111_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-118_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-100_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-113_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-109_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-120_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-101_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-107_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-111_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-121_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-109_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Copied sub-041_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/val
# Copied sub-008_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/val
# Copied sub-030_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/val
# Copied sub-053_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/val
# Copied sub-068_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/val
# Copied sub-040_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/val
# Copied sub-028_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/val
# Copied sub-046_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/val
# Copied sub-061_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-050_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-007_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-063_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-049_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-016_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-016_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-070_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-017_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-022_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-039_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-058_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-057_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-067_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-069_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-063_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Copied sub-041_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-008_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-030_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-053_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-068_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-040_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-028_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-046_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-061_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-050_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-007_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-063_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-049_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-016_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-016_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-070_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-017_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-022_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-039_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-058_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-057_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-067_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-069_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-063_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-015_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-064_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-025_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-023_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-047_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-039_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-067_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-001_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-039_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-061_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-038_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-069_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-016_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-041_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-021_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-031_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-006_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-032_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-017_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-031_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-055_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-065_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-049_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-064_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-053_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-032_ses-visit3_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-057_ses-visit4_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-066_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-059_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-028_ses-visit2_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-052_ses-visit1_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Copied sub-049_ses-visit5_T1w.nii to /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Data splitting complete.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
groups = ['healthy', 'chronic', 'subacute']
# Define 3D-CNN model
model = Sequential([
    Conv3D(32, kernel_size=(3, 3, 3), activation='relu', input_shape=(128, 128, 128, 1)),
    MaxPooling3D(pool_size=(2, 2, 2)),
    Conv3D(64, kernel_size=(3, 3, 3), activation='relu'),
    MaxPooling3D(pool_size=(2, 2, 2)),
    Conv3D(128, kernel_size=(3, 3, 3), activation='relu'),
    MaxPooling3D(pool_size=(2, 2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(len(groups), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import os
import numpy as np
import nibabel as nib
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Paths
base_dir = '/content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/'

splits = ['train', 'val', 'test']
groups = ['healthy', 'chronic', 'subacute']

def load_mri_data(base_dir, groups, splits):
    data = []
    labels = []
    for group_idx, group in enumerate(groups):
        for split in splits:
            split_dir = os.path.join(base_dir, group, split)
            for file_name in os.listdir(split_dir):
                if file_name.endswith('.nii'):
                    file_path = os.path.join(split_dir, file_name)
                    mri_image_nii = nib.load(file_path)
                    mri_image = mri_image_nii.get_fdata()
                    data.append(mri_image)
                    labels.append(group_idx)
    return np.array(data), np.array(labels)

# Load data
data, labels = load_mri_data(base_dir, groups, splits)

# Split data into train, validation, and test sets
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)
val_data, test_data, val_labels, test_labels = train_test_split(test_data, test_labels, test_size=0.5, random_state=42, stratify=test_labels)

# Normalize data
train_data = (train_data - np.min(train_data)) / (np.max(train_data) - np.min(train_data))
val_data = (val_data - np.min(val_data)) / (np.max(val_data) - np.min(val_data))
test_data = (test_data - np.min(test_data)) / (np.max(test_data) - np.min(test_data))

# Convert labels to categorical
train_labels = to_categorical(train_labels, num_classes=len(groups))
val_labels = to_categorical(val_labels, num_classes=len(groups))
test_labels = to_categorical(test_labels, num_classes=len(groups))



# Train the model
history = model.fit(train_data, train_labels, epochs=20, batch_size=6, validation_data=(val_data, val_labels))

# Evaluate the model
test_predictions = model.predict(test_data)
test_labels_pred = np.argmax(test_predictions, axis=1)
test_labels_true = np.argmax(test_labels, axis=1)

# Confusion Matrix
cm = confusion_matrix(test_labels_true, test_labels_pred)
print('Confusion Matrix:\n', cm)

# F1 Score
f1 = f1_score(test_labels_true, test_labels_pred, average='weighted')
print('F1 Score:', f1)

# Classification Report
report = classification_report(test_labels_true, test_labels_pred, target_names=groups)
print('Classification Report:\n', report)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=groups, yticklabels=groups)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-85ee02bc2a46> in <cell line: 54>()
#      52
#      53 # Train the model
# ---> 54 history = model.fit(train_data, train_labels, epochs=20, batch_size=6, validation_data=(val_data, val_labels))
#      55
#      56 # Evaluate the model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/nn.py in categorical_crossentropy(target, output, from_logits, axis)
#     552         )
#     553     if len(target.shape) != len(output.shape):
# --> 554         raise ValueError(
#     555             "Arguments `target` and `output` must have the same rank "
#     556             "(ndim). Received: "
#
# ValueError: Arguments `target` and `output` must have the same rank (ndim). Received: target.shape=(6, 3), output.shape=(6, 128, 128, 128, 3)

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import nibabel as nib
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Paths
base_dir = '/content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/'
groups = ['subacute', 'healthy', 'chronic']

# Function to load .nii files and preprocess
def load_nifti(path):
    img = nib.load(path).get_fdata()
    img = np.expand_dims(img, axis=-1)  # Add channel dimension
    img = tf.image.resize(img, [128, 128, 128])  # Resize to match model input
    img = img / 255.0  # Normalize to [0, 1]
    return img

def load_and_preprocess(file_path, label):
    # Ensure file_path is treated as a string
    file_path = file_path.numpy().decode('utf-8')
    img = load_nifti(file_path)
    img = np.expand_dims(img, axis=-1)  # Add channel dimension
    return img, tf.constant(groups.index(label))

def create_dataset_from_directory(directory, split_name, batch_size=32):
    file_paths = []
    labels = []
    for group in groups:
        split_dir = os.path.join(directory, group, split_name)
        print(f"Processing split directory: {split_dir}")
        for file_name in os.listdir(split_dir):
            print(f"Processing file: {file_name}")
            if file_name.endswith('.nii'):
                file_paths.append(os.path.join(split_dir, file_name))
                labels.append(group)

    # Create TensorFlow dataset
    dataset = tf.data.Dataset.from_tensor_slices((file_paths, labels))

    # Use tf.py_function to handle file path processing
    def tf_load_and_preprocess(file_path, label):
        img, lbl = tf.py_function(load_and_preprocess, [file_path, label], [tf.float32, tf.int64])
        img.set_shape((128, 128, 128, 1))  # Set shape for TensorFlow
        return img, lbl

    dataset = dataset.map(tf_load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(buffer_size=len(file_paths))
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

    return dataset

# Create datasets
train_ds = create_dataset_from_directory(base_dir, 'train')
val_ds = create_dataset_from_directory(base_dir, 'val')
test_ds = create_dataset_from_directory(base_dir, 'test')

# Define 3D CNN model
model = models.Sequential([
    layers.Conv3D(32, (3, 3, 3), activation='relu', input_shape=(128, 128, 128, 1)),
    layers.MaxPooling3D((2, 2, 2)),
    layers.Conv3D(64, (3, 3, 3), activation='relu'),
    layers.MaxPooling3D((2, 2, 2)),
    layers.Conv3D(128, (3, 3, 3), activation='relu'),
    layers.MaxPooling3D((2, 2, 2)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(len(groups), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test Accuracy: {test_acc}")

# Predict on test set
y_true = []
y_pred = []

for images, labels in test_ds:
    predictions = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))

# Calculate and plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=groups, yticklabels=groups)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
print(classification_report(y_true, y_pred, target_names=groups))
# Out:
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Processing file: subacute_sub-032_ses-visit1_T1w.nii
# Processing file: subacute_sub-028_ses-visit3_T1w.nii
# Processing file: subacute_sub-015_ses-visit2_T1w.nii
# Processing file: subacute_sub-068_ses-visit1_T1w.nii
# Processing file: subacute_sub-061_ses-visit5_T1w.nii
# Processing file: subacute_sub-033_ses-visit4_T1w.nii
# Processing file: subacute_sub-067_ses-visit4_T1w.nii
# Processing file: subacute_sub-069_ses-visit4_T1w.nii
# Processing file: subacute_sub-024_ses-visit5_T1w.nii
# Processing file: subacute_sub-057_ses-visit4_T1w.nii
# Processing file: subacute_sub-044_ses-visit4_T1w.nii
# Processing file: subacute_sub-055_ses-visit4_T1w.nii
# Processing file: subacute_sub-058_ses-visit3_T1w.nii
# Processing file: subacute_sub-037_ses-visit4_T1w.nii
# Processing file: subacute_sub-038_ses-visit5_T1w.nii
# Processing file: subacute_sub-019_ses-visit5_T1w.nii
# Processing file: subacute_sub-063_ses-visit2_T1w.nii
# Processing file: subacute_sub-020_ses-visit3_T1w.nii
# Processing file: subacute_sub-047_ses-visit3_T1w.nii
# Processing file: subacute_sub-051_ses-visit2_T1w.nii
# Processing file: subacute_sub-062_ses-visit3_T1w.nii
# Processing file: subacute_sub-069_ses-visit5_T1w.nii
# Processing file: subacute_sub-036_ses-visit5_T1w.nii
# Processing file: subacute_sub-055_ses-visit2_T1w.nii
# Processing file: subacute_sub-048_ses-visit4_T1w.nii
# Processing file: subacute_sub-009_ses-visit5_T1w.nii
# Processing file: subacute_sub-005_ses-visit4_T1w.nii
# Processing file: subacute_sub-057_ses-visit5_T1w.nii
# Processing file: subacute_sub-036_ses-visit3_T1w.nii
# Processing file: subacute_sub-043_ses-visit3_T1w.nii
# Processing file: subacute_sub-012_ses-visit4_T1w.nii
# Processing file: subacute_sub-046_ses-visit4_T1w.nii
# Processing file: subacute_sub-006_ses-visit1_T1w.nii
# Processing file: subacute_sub-063_ses-visit1_T1w.nii
# Processing file: subacute_sub-018_ses-visit2_T1w.nii
# Processing file: subacute_sub-033_ses-visit1_T1w.nii
# Processing file: subacute_sub-070_ses-visit1_T1w.nii
# Processing file: subacute_sub-060_ses-visit1_T1w.nii
# Processing file: subacute_sub-038_ses-visit1_T1w.nii
# Processing file: subacute_sub-068_ses-visit5_T1w.nii
# Processing file: subacute_sub-029_ses-visit1_T1w.nii
# Processing file: subacute_sub-028_ses-visit4_T1w.nii
# Processing file: subacute_sub-014_ses-visit3_T1w.nii
# Processing file: subacute_sub-013_ses-visit3_T1w.nii
# Processing file: subacute_sub-008_ses-visit2_T1w.nii
# Processing file: subacute_sub-019_ses-visit3_T1w.nii
# Processing file: subacute_sub-060_ses-visit2_T1w.nii
# Processing file: subacute_sub-061_ses-visit3_T1w.nii
# Processing file: subacute_sub-032_ses-visit3_T1w.nii
# Processing file: subacute_sub-002_ses-visit4_T1w.nii
# Processing file: subacute_sub-060_ses-visit5_T1w.nii
# Processing file: subacute_sub-041_ses-visit1_T1w.nii
# Processing file: subacute_sub-035_ses-visit1_T1w.nii
# Processing file: subacute_sub-039_ses-visit3_T1w.nii
# Processing file: subacute_sub-047_ses-visit4_T1w.nii
# Processing file: subacute_sub-023_ses-visit4_T1w.nii
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Processing file: healthy_sub-079_ses-visit3_T1w.nii
# Processing file: healthy_sub-074_ses-visit3_T1w.nii
# Processing file: healthy_sub-073_ses-visit1_T1w.nii
# Processing file: healthy_sub-082_ses-visit2_T1w.nii
# Processing file: healthy_sub-077_ses-visit2_T1w.nii
# Processing file: healthy_sub-087_ses-visit3_T1w.nii
# Processing file: healthy_sub-071_ses-visit2_T1w.nii
# Processing file: healthy_sub-084_ses-visit4_T1w.nii
# Processing file: healthy_sub-086_ses-visit3_T1w.nii
# Processing file: healthy_sub-072_ses-visit1_T1w.nii
# Processing file: healthy_sub-088_ses-visit2_T1w.nii
# Processing file: healthy_sub-096_ses-visit1_T1w.nii
# Processing file: healthy_sub-079_ses-visit4_T1w.nii
# Processing file: healthy_sub-081_ses-visit4_T1w.nii
# Processing file: healthy_sub-077_ses-visit3_T1w.nii
# Processing file: healthy_sub-077_ses-visit4_T1w.nii
# Processing file: healthy_sub-087_ses-visit2_T1w.nii
# Processing file: healthy_sub-090_ses-visit2_T1w.nii
# Processing file: healthy_sub-073_ses-visit4_T1w.nii
# Processing file: healthy_sub-080_ses-visit4_T1w.nii
# Processing file: healthy_sub-089_ses-visit3_T1w.nii
# Processing file: healthy_sub-076_ses-visit2_T1w.nii
# Processing file: healthy_sub-071_ses-visit3_T1w.nii
# Processing file: healthy_sub-078_ses-visit1_T1w.nii
# Processing file: healthy_sub-096_ses-visit3_T1w.nii
# Processing file: healthy_sub-076_ses-visit3_T1w.nii
# Processing file: healthy_sub-072_ses-visit2_T1w.nii
# Processing file: healthy_sub-090_ses-visit1_T1w.nii
# Processing file: healthy_sub-085_ses-visit4_T1w.nii
# Processing file: healthy_sub-075_ses-visit2_T1w.nii
# Processing file: healthy_sub-082_ses-visit3_T1w.nii
# Processing file: healthy_sub-074_ses-visit1_T1w.nii
# Processing file: healthy_sub-096_ses-visit2_T1w.nii
# Processing file: healthy_sub-079_ses-visit1_T1w.nii
# Processing file: healthy_sub-084_ses-visit2_T1w.nii
# Processing file: healthy_sub-091_ses-visit1_T1w.nii
# Processing file: healthy_sub-085_ses-visit2_T1w.nii
# Processing file: healthy_sub-086_ses-visit1_T1w.nii
# Processing file: healthy_sub-083_ses-visit1_T1w.nii
# Processing file: healthy_sub-082_ses-visit4_T1w.nii
# Processing file: healthy_sub-081_ses-visit3_T1w.nii
# Processing file: healthy_sub-090_ses-visit4_T1w.nii
# Processing file: healthy_sub-088_ses-visit4_T1w.nii
# Processing file: healthy_sub-087_ses-visit4_T1w.nii
# Processing file: healthy_sub-091_ses-visit3_T1w.nii
# Processing file: healthy_sub-081_ses-visit1_T1w.nii
# Processing file: healthy_sub-082_ses-visit1_T1w.nii
# Processing file: healthy_sub-084_ses-visit1_T1w.nii
# Processing file: healthy_sub-083_ses-visit4_T1w.nii
# Processing file: healthy_sub-091_ses-visit2_T1w.nii
# Processing file: healthy_sub-071_ses-visit4_T1w.nii
# Processing file: healthy_sub-089_ses-visit2_T1w.nii
# Processing file: healthy_sub-072_ses-visit3_T1w.nii
# Processing file: healthy_sub-087_ses-visit1_T1w.nii
# Processing file: healthy_sub-089_ses-visit4_T1w.nii
# Processing file: healthy_sub-086_ses-visit4_T1w.nii
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Processing file: chronic_sub-121_ses-visit1_T1w.nii
# Processing file: chronic_sub-118_ses-visit1_T1w.nii
# Processing file: chronic_sub-099_ses-visit1_T1w.nii
# Processing file: chronic_sub-097_ses-visit2_T1w.nii
# Processing file: chronic_sub-098_ses-visit4_T1w.nii
# Processing file: chronic_sub-105_ses-visit3_T1w.nii
# Processing file: chronic_sub-098_ses-visit3_T1w.nii
# Processing file: chronic_sub-119_ses-visit4_T1w.nii
# Processing file: chronic_sub-110_ses-visit1_T1w.nii
# Processing file: chronic_sub-119_ses-visit1_T1w.nii
# Processing file: chronic_sub-111_ses-visit2_T1w.nii
# Processing file: chronic_sub-108_ses-visit1_T1w.nii
# Processing file: chronic_sub-109_ses-visit2_T1w.nii
# Processing file: chronic_sub-115_ses-visit4_T1w.nii
# Processing file: chronic_sub-113_ses-visit4_T1w.nii
# Processing file: chronic_sub-108_ses-visit3_T1w.nii
# Processing file: chronic_sub-116_ses-visit1_T1w.nii
# Processing file: chronic_sub-120_ses-visit2_T1w.nii
# Processing file: chronic_sub-112_ses-visit3_T1w.nii
# Processing file: chronic_sub-100_ses-visit1_T1w.nii
# Processing file: chronic_sub-098_ses-visit1_T1w.nii
# Processing file: chronic_sub-109_ses-visit3_T1w.nii
# Processing file: chronic_sub-117_ses-visit2_T1w.nii
# Processing file: chronic_sub-113_ses-visit2_T1w.nii
# Processing file: chronic_sub-103_ses-visit3_T1w.nii
# Processing file: chronic_sub-117_ses-visit1_T1w.nii
# Processing file: chronic_sub-101_ses-visit2_T1w.nii
# Processing file: chronic_sub-119_ses-visit2_T1w.nii
# Processing file: chronic_sub-119_ses-visit3_T1w.nii
# Processing file: chronic_sub-106_ses-visit1_T1w.nii
# Processing file: chronic_sub-108_ses-visit4_T1w.nii
# Processing file: chronic_sub-111_ses-visit4_T1w.nii
# Processing file: chronic_sub-116_ses-visit4_T1w.nii
# Processing file: chronic_sub-118_ses-visit3_T1w.nii
# Processing file: chronic_sub-120_ses-visit4_T1w.nii
# Processing file: chronic_sub-106_ses-visit4_T1w.nii
# Processing file: chronic_sub-117_ses-visit3_T1w.nii
# Processing file: chronic_sub-107_ses-visit3_T1w.nii
# Processing file: chronic_sub-102_ses-visit2_T1w.nii
# Processing file: chronic_sub-108_ses-visit2_T1w.nii
# Processing file: chronic_sub-104_ses-visit1_T1w.nii
# Processing file: chronic_sub-102_ses-visit1_T1w.nii
# Processing file: chronic_sub-097_ses-visit4_T1w.nii
# Processing file: chronic_sub-100_ses-visit4_T1w.nii
# Processing file: chronic_sub-101_ses-visit4_T1w.nii
# Processing file: chronic_sub-109_ses-visit1_T1w.nii
# Processing file: chronic_sub-112_ses-visit4_T1w.nii
# Processing file: chronic_sub-097_ses-visit1_T1w.nii
# Processing file: chronic_sub-105_ses-visit2_T1w.nii
# Processing file: chronic_sub-105_ses-visit4_T1w.nii
# Processing file: chronic_sub-112_ses-visit1_T1w.nii
# Processing file: chronic_sub-113_ses-visit1_T1w.nii
# Processing file: chronic_sub-100_ses-visit3_T1w.nii
# Processing file: chronic_sub-109_ses-visit4_T1w.nii
# Processing file: chronic_sub-102_ses-visit3_T1w.nii
# Processing file: chronic_sub-115_ses-visit1_T1w.nii
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/val
# Processing file: subacute_sub-032_ses-visit1_T1w.nii
# Processing file: subacute_sub-028_ses-visit3_T1w.nii
# Processing file: subacute_sub-015_ses-visit2_T1w.nii
# Processing file: subacute_sub-068_ses-visit1_T1w.nii
# Processing file: subacute_sub-061_ses-visit5_T1w.nii
# Processing file: subacute_sub-033_ses-visit4_T1w.nii
# Processing file: subacute_sub-067_ses-visit4_T1w.nii
# Processing file: subacute_sub-069_ses-visit4_T1w.nii
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/val
# Processing file: healthy_sub-080_ses-visit3_T1w.nii
# Processing file: healthy_sub-080_ses-visit2_T1w.nii
# Processing file: healthy_sub-077_ses-visit1_T1w.nii
# Processing file: healthy_sub-073_ses-visit2_T1w.nii
# Processing file: healthy_sub-083_ses-visit3_T1w.nii
# Processing file: healthy_sub-091_ses-visit4_T1w.nii
# Processing file: healthy_sub-088_ses-visit3_T1w.nii
# Processing file: healthy_sub-074_ses-visit2_T1w.nii
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/val
# Processing file: chronic_sub-111_ses-visit3_T1w.nii
# Processing file: chronic_sub-115_ses-visit3_T1w.nii
# Processing file: chronic_sub-107_ses-visit1_T1w.nii
# Processing file: chronic_sub-110_ses-visit2_T1w.nii
# Processing file: chronic_sub-103_ses-visit1_T1w.nii
# Processing file: chronic_sub-121_ses-visit3_T1w.nii
# Processing file: chronic_sub-114_ses-visit1_T1w.nii
# Processing file: chronic_sub-105_ses-visit1_T1w.nii
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Processing file: subacute_sub-024_ses-visit5_T1w.nii
# Processing file: subacute_sub-057_ses-visit4_T1w.nii
# Processing file: subacute_sub-044_ses-visit4_T1w.nii
# Processing file: subacute_sub-055_ses-visit4_T1w.nii
# Processing file: subacute_sub-058_ses-visit3_T1w.nii
# Processing file: subacute_sub-037_ses-visit4_T1w.nii
# Processing file: subacute_sub-038_ses-visit5_T1w.nii
# Processing file: subacute_sub-019_ses-visit5_T1w.nii
# Processing file: subacute_sub-063_ses-visit2_T1w.nii
# Processing file: subacute_sub-020_ses-visit3_T1w.nii
# Processing file: subacute_sub-047_ses-visit3_T1w.nii
# Processing file: subacute_sub-051_ses-visit2_T1w.nii
# Processing file: subacute_sub-062_ses-visit3_T1w.nii
# Processing file: subacute_sub-069_ses-visit5_T1w.nii
# Processing file: subacute_sub-036_ses-visit5_T1w.nii
# Processing file: subacute_sub-055_ses-visit2_T1w.nii
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Processing file: healthy_sub-080_ses-visit1_T1w.nii
# Processing file: healthy_sub-075_ses-visit3_T1w.nii
# Processing file: healthy_sub-079_ses-visit2_T1w.nii
# Processing file: healthy_sub-083_ses-visit2_T1w.nii
# Processing file: healthy_sub-090_ses-visit3_T1w.nii
# Processing file: healthy_sub-078_ses-visit3_T1w.nii
# Processing file: healthy_sub-075_ses-visit4_T1w.nii
# Processing file: healthy_sub-076_ses-visit4_T1w.nii
# Processing file: healthy_sub-085_ses-visit3_T1w.nii
# Processing file: healthy_sub-071_ses-visit1_T1w.nii
# Processing file: healthy_sub-084_ses-visit3_T1w.nii
# Processing file: healthy_sub-076_ses-visit1_T1w.nii
# Processing file: healthy_sub-074_ses-visit4_T1w.nii
# Processing file: healthy_sub-081_ses-visit2_T1w.nii
# Processing file: healthy_sub-089_ses-visit1_T1w.nii
# Processing file: healthy_sub-088_ses-visit1_T1w.nii
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# Processing file: chronic_sub-100_ses-visit2_T1w.nii
# Processing file: chronic_sub-120_ses-visit3_T1w.nii
# Processing file: chronic_sub-118_ses-visit4_T1w.nii
# Processing file: chronic_sub-116_ses-visit3_T1w.nii
# Processing file: chronic_sub-103_ses-visit2_T1w.nii
# Processing file: chronic_sub-120_ses-visit1_T1w.nii
# Processing file: chronic_sub-116_ses-visit2_T1w.nii
# Processing file: chronic_sub-106_ses-visit2_T1w.nii
# Processing file: chronic_sub-107_ses-visit4_T1w.nii
# Processing file: chronic_sub-103_ses-visit4_T1w.nii
# Processing file: chronic_sub-107_ses-visit2_T1w.nii
# Processing file: chronic_sub-121_ses-visit2_T1w.nii
# Processing file: chronic_sub-102_ses-visit4_T1w.nii
# Processing file: chronic_sub-118_ses-visit2_T1w.nii
# Processing file: chronic_sub-114_ses-visit4_T1w.nii
# Processing file: chronic_sub-112_ses-visit2_T1w.nii
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-690b0311a8cd> in <cell line: 81>()
#      79
#      80 # Train the model
# ---> 81 history = model.fit(
#      82     train_ds,
#      83     validation_data=val_ds,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses/loss.py in squeeze_or_expand_to_same_rank(x1, x2, expand_rank_1)
#      88 def squeeze_or_expand_to_same_rank(x1, x2, expand_rank_1=True):
#      89     """Squeeze/expand last dim if ranks differ from expected by exactly 1."""
# ---> 90     x1_rank = len(x1.shape)
#      91     x2_rank = len(x2.shape)
#      92     if x1_rank == x2_rank:
#
# ValueError: Cannot take the length of shape with unknown rank.

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import nibabel as nib
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Paths
base_dir = '/content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/'
groups = ['subacute', 'healthy', 'chronic']

# Function to load, normalize, and resize MRI data
def load_and_process_mri(file_path):
    try:
        img = nib.load(file_path)
        img_data = img.get_fdata()
        return img_data
    except Exception as e:
        print(f"Error loading or processing {file_path}: {e}")
        return None

def create_dataset_from_directory(directory, split_name, batch_size=32):
    file_paths = []
    labels = []
    dataset = []
    for group in groups:
        split_dir = os.path.join(directory, group, split_name)
        print(f"Processing split directory: {split_dir}")
        for file_name in os.listdir(split_dir):
            if file_name.endswith('.nii'):
                file_paths.append(os.path.join(split_dir, file_name))
                labels.append(group)
                dataset.append(load_and_process_mri(os.path.join(split_dir, file_name)))

    return dataset, labels

# Create datasets
train_ds = create_dataset_from_directory(base_dir, 'train')
val_ds = create_dataset_from_directory(base_dir, 'val')
test_ds = create_dataset_from_directory(base_dir, 'test')




# Define 3D CNN model
model = models.Sequential([
    layers.Conv3D(32, (3, 3, 3), activation='relu', input_shape=(128, 128, 128, 1)),
    layers.MaxPooling3D((2, 2, 2)),
    layers.Conv3D(64, (3, 3, 3), activation='relu'),
    layers.MaxPooling3D((2, 2, 2)),
    layers.Conv3D(128, (3, 3, 3), activation='relu'),
    layers.MaxPooling3D((2, 2, 2)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(len(groups), activation='softmax')
])

# Define the model
def create_model(input_shape):
    model = Sequential([
        Conv3D(32, (3, 3, 3), activation='relu', input_shape=input_shape),
        MaxPooling3D((2, 2, 2)),
        Conv3D(64, (3, 3, 3), activation='relu'),
        MaxPooling3D((2, 2, 2)),
        Conv3D(128, (3, 3, 3), activation='relu'),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(len(groups), activation='softmax')
    ])
    return model
# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test Accuracy: {test_acc}")

# Predict on test set
y_true = []
y_pred = []

for images, labels in test_ds:
    predictions = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))

# Calculate and plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=groups, yticklabels=groups)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
print(classification_report(y_true, y_pred, target_names=groups))
# Out:
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Shape of train_ds: [memmap([[0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405],
#         [0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405],
#         [0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405],
#         ...,
#         [0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405],
#         [0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405],
#         [0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405]]), memmap([[0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973],
#         [0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973],
#         [0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973],
#         ...,
#         [0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973],
#         [0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973],
#         [0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973]]), memmap([[0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057],
#         [0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057],
#         [0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057],
#         ...,
#         [0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057],
#         [0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057],
#         [0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057]]), memmap([[0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785],
#         [0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785],
#         [0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785],
#         ...,
#         [0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785],
#         [0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785],
#         [0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785]]), memmap([[0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795],
#         [0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795],
#         [0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795],
#         ...,
#         [0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795],
#         [0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795],
#         [0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795]]), memmap([[0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ],
#         [0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ],
#         [0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ],
#         ...,
#         [0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ],
#         [0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ],
#         [0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ]]), memmap([[0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019],
#         [0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019],
#         [0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019],
#         ...,
#         [0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019],
#         [0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019],
#         [0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019]]), memmap([[0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032851],
#         [0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032851],
#         [0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032851],
#         ...,
#         [0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032851],
#         [0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032851],
#         [0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032
#          0.0117043 ],
#         [0.22725594, 0.22687005, 0.21279353, ..., 0.22177263, 0.20824312,
#          0.0117043 ],
#         ...,
#         [0.22725594, 0.22687005, 0.21279353, ..., 0.22177263, 0.20824312,
#          0.0117043 ],
#         [0.22725594, 0.22687005, 0.21279353, ..., 0.22177263, 0.20824312,
#          0.0117043 ],
#         [0.22725594, 0.22687005, 0.21279353, ..., 0.22177263, 0.20824312,
#          0.0117043 ]]), memmap([[0.0151967 , 0.01517851, 0.01516849, ..., 0.01536833, 0.00923048,
#          0.00053199],
#         [0.0151967 , 0.01517851, 0.01516849, ..., 0.01536833, 0.00923048,
#          0.00053199],
#         [0.0151967 , 0.01517851, 0.01516849, ..., 0.01536833, 0.00923048,
#          0.00053199],
#         ...,
#         [0.0151967 , 0.01517851, 0.01516849, ..., 0.01536833, 0.00923048,
#          0.00053199],
#         [0.0151967 , 0.01517851, 0.01516849, ..., 0.01536833, 0.00923048,
#          0.00053199],
#         [0.0151967 , 0.01517851, 0.01516849, ..., 0.01536833, 0.00923048,
#          0.00053199]]), memmap([[0.01442242, 0.01610079, 0.01821053, ..., 0.14198291, 0.0616373 ,
#          0.00122864],
#         [0.01442242, 0.01610079, 0.01821053, ..., 0.14198291, 0.0616373 ,
#          0.00122864],
#         [0.01442242, 0.01610079, 0.01821053, ..., 0.14198291, 0.0616373 ,
#          0.00122864],
#         ...,
#         [0.01442242, 0.01610079, 0.01821053, ..., 0.14198291, 0.0616373 ,
#          0.00122864],
#         [0.01442242, 0.01610079, 0.01821053, ..., 0.14198291, 0.0616373 ,
#          0.00122864],
#         [0.01442242, 0.01610079, 0.01821053, ..., 0.14198291, 0.0616373 ,
#          0.00122864]]), memmap([[0.01304296, 0.01265033, 0.01231805, ..., 0.19294144, 0.13770264,
#          0.00593653],
#         [0.01304296, 0.01265033, 0.01231805, ..., 0.19294144, 0.13770264,
#          0.00593653],
#         [0.01304296, 0.01265033, 0.01231805, ..., 0.19294144, 0.13770264,
#          0.00593653],
#         ...,
#         [0.01304296, 0.01265033, 0.01231805, ..., 0.19294144, 0.13770264,
#          0.00593653],
#         [0.01304296, 0.01265033, 0.01231805, ..., 0.19294144, 0.13770264,
#          0.00593653],
#         [0.01304296, 0.01265033, 0.01231805, ..., 0.19294144, 0.13770264,
#          0.00593653]]), memmap([[0.16922958, 0.16861704, 0.17078504, ..., 0.10282387, 0.07489731,
#          0.00142769],
#         [0.16922958, 0.16861704, 0.17078504, ..., 0.10282387, 0.07489731,
#          0.00142769],
#         [0.16922958, 0.16861704, 0.17078504, ..., 0.10282387, 0.07489731,
#          0.00142769],
#         ...,
#         [0.16922958, 0.16861704, 0.17078504, ..., 0.10282387, 0.07489731,
#          0.00142769],
#         [0.16922958, 0.16861704, 0.17078504, ..., 0.10282387, 0.07489731,
#          0.00142769],
#         [0.16922958, 0.16861704, 0.17078504, ..., 0.10282387, 0.07489731,
#          0.00142769]]), memmap([[2.21358135e-01, 2.20201346e-01, 2.16975467e-01, ...,
#          0.00031386],
#         [0.01465652, 0.01482352, 0.01516224, ..., 0.01020469, 0.00471787,
#          0.00031386],
#         [0.01465652, 0.01482352, 0.01516224, ..., 0.01020469, 0.00471787,
#          0.00031386]]), memmap([[0.01675094, 0.01641515, 0.01631417, ..., 0.02424818, 0.01014135,
#          0.00040934],
#         [0.01675094, 0.01641515, 0.01631417, ..., 0.02424818, 0.01014135,
#          0.00040934],
#         [0.01675094, 0.01641515, 0.01631417, ..., 0.02424818, 0.01014135,
#          0.00040934],
#         ...,
#         [0.01675094, 0.01641515, 0.01631417, ..., 0.02424818, 0.01014135,
#          0.00040934],
#         [0.01675094, 0.01641515, 0.01631417, ..., 0.02424818, 0.01014135,
#          0.00040934],
#         [0.01675094, 0.01641515, 0.01631417, ..., 0.02424818, 0.01014135,
#          0.00040934]]), memmap([[0.02036543, 0.02389319, 0.01912497, ..., 0.02016152, 0.00936529,
#          0.00066954],
#         [0.02036543, 0.02389319, 0.01912497, ..., 0.02016152, 0.00936529,
#          0.00066954],
#         [0.02036543, 0.02389319, 0.01912497, ..., 0.02016152, 0.00936529,
#          0.00066954],
#         ...,
#         [0.02036543, 0.02389319, 0.01912497, ..., 0.02016152, 0.00936529,
#          0.00066954],
#         [0.02036543, 0.02389319, 0.01912497, ..., 0.02016152, 0.00936529,
#          0.00066954],
#         [0.02036543, 0.02389319, 0.01912497, ..., 0.02016152, 0.00936529,
#          0.00066954]]), memmap([[0.0118939 , 0.0125017 , 0.01294361, ..., 0.01930839, 0.00846321,
#          0.00040107],
#         [0.0118939 , 0.0125017 , 0.01294361, ..., 0.01930839, 0.00846321,
#          0.00040107],
#         [0.0118939 , 0.0125017 , 0.01294361, ..., 0.01930839, 0.00846321,
#          0.00040107],
#         ...,
#         [0.0118939 , 0.0125017 , 0.01294361, ..., 0.01930839, 0.00846321,
#          0.00040107],
#         [0.0118939 , 0.0125017 , 0.01294361, ..., 0.01930839, 0.00846321,
#          0.00040107],
#         [0.0118939 , 0.0125017 , 0.01294361, ..., 0.01930839, 0.00846321,
#          0.00040107]]), memmap([[0.35458767, 0.36719287, 0.36320614, ..., 0.35436822, 0.1713141 ,
#          0.00074514],
#         [0.35458767, 0.36719287, 0.36320614, ..., 0.35436822, 0.1713141 ,
#          0.00074514],
#         [0.35458767, 0.36719287, 0.36320614, ..., 0.35436822, 0.1713141 ,
#          0.00074514],
#         ...,
#         [0.35458767, 0.36719287, 0.36320614, ..., 0.35436822, 0.1713141 ,
#          0.00074514],
#         [0.35458767, 0.36719287, 0.36320614, ..., 0.35436822, 0.1713141 ,
#          0.00074514],
#         [0.35458767, 0.36719287, 0.36320614, ..., 0.35436822, 0.1713141 ,
#          0.00074514]]), memmap([[0.01282808, 0.0140152 , 0.01473752, ..., 0.05329374, 0.01124551,
#          0.00035504],
#         [0.01282808, 0.0140152 , 0.01473752, ..., 0.05329374, 0.01124551,
#          0.00035504],
#         [0.01282808, 0.0140152 , 0.01473752, ..., 0.05329374, 0.01124551,
#          2.03327065e-01, 1.00305107e-01, 1.61832147e-04],
#         [2.03379016e-01, 2.02605518e-01, 2.02059592e-01, ...,
#          2.03327065e-01, 1.00305107e-01, 1.61832147e-04],
#         [2.03379016e-01, 2.02605518e-01, 2.02059592e-01, ...,
#          2.03327065e-01, 1.00305107e-01, 1.61832147e-04],
#         ...,
#         [2.03379016e-01, 2.02605518e-01, 2.02059592e-01, ...,
#          2.03327065e-01, 1.00305107e-01, 1.61832147e-04],
#         [2.03379016e-01, 2.02605518e-01, 2.02059592e-01, ...,
#          2.03327065e-01, 1.00305107e-01, 1.61832147e-04],
#         [2.03379016e-01, 2.02605518e-01, 2.02059592e-01, ...,
#          2.03327065e-01, 1.00305107e-01, 1.61832147e-04]]), memmap([[0.27022609, 0.26878283, 0.26870831, ..., 0.15616556, 0.11201375,
#          0.00131558],
#         [0.27022609, 0.26878283, 0.26870831, ..., 0.15616556, 0.11201375,
#          0.00131558],
#         [0.27022609, 0.26878283, 0.26870831, ..., 0.15616556, 0.11201375,
#          0.00131558],
#         ...,
#         [0.27022609, 0.26878283, 0.26870831, ..., 0.15616556, 0.11201375,
#          0.00131558],
#         [0.27022609, 0.26878283, 0.26870831, ..., 0.15616556, 0.11201375,
#          0.00131558],
#         [0.27022609, 0.26878283, 0.26870831, ..., 0.15616556, 0.11201375,
#          0.00131558]]), memmap([[0.16883103, 0.16315998, 0.11776196, ..., 0.12685494, 0.06905893,
#          0.0005946 ],
#         [0.16883103, 0.16315998, 0.11776196, ..., 0.12685494, 0.06905893,
#          0.0005946 ],
#         [0.16883103, 0.16315998, 0.11776196, ..., 0.12685494, 0.06905893,
#          0.0005946 ],
#         ...,
#         [0.16883103, 0.16315998, 0.11776196, ..., 0.12685494, 0.06905893,
#          0.0005946 ],
#         [0.16883103, 0.16315998, 0.11776196, ..., 0.12685494, 0.06905893,
#          0.0005946 ],
#         [0.16883103, 0.16315998, 0.11776196, ..., 0.12685494, 0.06905893,
#          0.0005946 ]]), memmap([[0.17326072, 0.16574319, 0.19583938, ..., 0.18542768, 0.1068482 ,
#          0.00296674],
#         [0.17326072, 0.16574319, 0.19583938, ..., 0.18542768, 0.1068482 ,
#          0.00296674],
#         [0.17326072, 0.16574319, 0.19583938, ..., 0.18542768, 0.1068482 ,
#          0.00296674],
#         ...,
#         [0.17326072, 0.16574319, 0.19583938, ..., 0.18542768, 0.1068482 ,
#          0.00296674],
#         [0.17326072, 0.16574319, 0.19583938, ..., 0.18542768, 0.1068482 ,
#          0.00296674],
#         [0.17326072, 0.16574319, 0.19583938, ..., 0.18542768, 0.1068482 ,
#          0.00296674]]), memmap([[0.17077549, 0.17507408, 0.17626452, ..., 0.01119285, 0.00404465,
#          0.00088091],
#         [0.17077549, 0.17507408, 0.17626452, ..., 0.01119285, 0.00404465,
#          0.00088091],
#         [0.17077549, 0.17507408, 0.17626452, ..., 0.01119285, 0.00404465,
#          0.00088091],
#         ...,
#         [0.17077549, 0.17507408, 0.17626452, ..., 0.01119285, 0.00404465,
#         [2.61785705e-01, 2.45905022e-01, 2.29351737e-01, ...,
#          2.17890466e-01, 1.01631233e-01, 2.02105568e-04],
#         ...,
#         [2.61785705e-01, 2.45905022e-01, 2.29351737e-01, ...,
#          2.17890466e-01, 1.01631233e-01, 2.02105568e-04],
#         [2.61785705e-01, 2.45905022e-01, 2.29351737e-01, ...,
#          2.17890466e-01, 1.01631233e-01, 2.02105568e-04],
#         [2.61785705e-01, 2.45905022e-01, 2.29351737e-01, ...,
#          2.17890466e-01, 1.01631233e-01, 2.02105568e-04]]), memmap([[0.2929725 , 0.29303722, 0.29284739, ..., 0.29097664, 0.2341192 ,
#          0.01087509],
#         [0.2929725 , 0.29303722, 0.29284739, ..., 0.29097664, 0.2341192 ,
#          0.01087509],
#         [0.2929725 , 0.29303722, 0.29284739, ..., 0.29097664, 0.2341192 ,
#          0.01087509],
#         ...,
#         [0.2929725 , 0.29303722, 0.29284739, ..., 0.29097664, 0.2341192 ,
#          0.01087509],
#         [0.2929725 , 0.29303722, 0.29284739, ..., 0.29097664, 0.2341192 ,
#          0.01087509],
#         [0.2929725 , 0.29303722, 0.29284739, ..., 0.29097664, 0.2341192 ,
#          0.01087509]]), memmap([[0.20448442, 0.20095942, 0.20258603, ..., 0.18559926, 0.08054128,
#          0.00024535],
#         [0.20448442, 0.20095942, 0.20258603, ..., 0.18559926, 0.08054128,
#          0.00024535],
#         [0.20448442, 0.20095942, 0.20258603, ..., 0.18559926, 0.08054128,
#          0.00024535],
#         ...,
#         [0.20448442, 0.20095942, 0.20258603, ..., 0.18559926, 0.08054128,
#          0.00024535],
#         [0.20448442, 0.20095942, 0.20258603, ..., 0.18559926, 0.08054128,
#          0.00024535],
#         [0.20448442, 0.20095942, 0.20258603, ..., 0.18559926, 0.08054128,
#          0.00024535]]), memmap([[0.20714637, 0.20754506, 0.20769955, ..., 0.19945818, 0.11591333,
#          0.00254096],
#         [0.20714637, 0.20754506, 0.20769955, ..., 0.19945818, 0.11591333,
#          0.00254096],
#         [0.20714637, 0.20754506, 0.20769955, ..., 0.19945818, 0.11591333,
#          0.00254096],
#         ...,
#         [0.20714637, 0.20754506, 0.20769955, ..., 0.19945818, 0.11591333,
#          0.00254096],
#         [0.20714637, 0.20754506, 0.20769955, ..., 0.19945818, 0.11591333,
#          0.00254096],
#         [0.20714637, 0.20754506, 0.20769955, ..., 0.19945818, 0.11591333,
#          0.00254096]]), memmap([[3.48056631e-01, 3.51017426e-01, 3.51469366e-01, ...,
#          3.30352456e-01, 1.68137873e-01, 3.06032154e-04],
#         [3.48056631e-01, 3.51017426e-01, 3.51469366e-01, ...,
#          3.30352456e-01, 1.68137873e-01, 3.06032154e-04],
#         [3.48056631e-01, 3.51017426e-01, 3.51469366e-01, ...,
#          3.30352456e-01, 1.68137873e-01, 3.06032154e-04],
#         ...,
#         [3.48056631e-01, 3.51017426e-01, 3.51469366e-01, ...,
#          3.30352456e-01, 1.68137873e-01, 3.06032154e-04],
#         [3.48056631e-01, 3.51017426e-01, 3.51469366e-01, ...,
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-8d53166ec0e0> in <cell line: 64>()
#      62
#      63 # Train the model
# ---> 64 history = model.fit(
#      65     train_ds,
#      66     validation_data=val_ds,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/data_adapter_utils.py in unpack_x_y_sample_weight(data)
#      48         f"or `(x, y, sample_weight)`, found: {data}"
#      49     )
# ---> 50     raise ValueError(error_msg)
#      51
#      52
#
# ValueError: Data is expected to be in format `x`, `(x,)`, `(x, y)`, or `(x, y, sample_weight)`, found: (memmap([[0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405],
#         [0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405],
#         [0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405],
#         ...,
#         [0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405],
#         [0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405],
#         [0.13989195, 0.13989838, 0.14141624, ..., 0.14533508, 0.06802088,
#          0.00096405]]), memmap([[0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973],
#         [0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973],
#         [0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973],
#         ...,
#         [0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973],
#         [0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973],
#         [0.22692316, 0.22634406, 0.22559376, ..., 0.21302372, 0.11324579,
#          0.00127973]]), memmap([[0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057],
#         [0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057],
#         [0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057],
#         ...,
#         [0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057],
#         [0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057],
#         [0.27462444, 0.27421806, 0.27273541, ..., 0.26280659, 0.1339638 ,
#          0.00056057]]), memmap([[0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785],
#         [0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785],
#         [0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785],
#         ...,
#         [0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785],
#         [0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785],
#         [0.01410173, 0.01516936, 0.01544741, ..., 0.01049503, 0.00710657,
#          0.00054785]]), memmap([[0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795],
#         [0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795],
#         [0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795],
#         ...,
#         [0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795],
#         [0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795],
#         [0.03046864, 0.0218954 , 0.02106655, ..., 0.002235  , 0.00109566,
#          0.00040795]]), memmap([[0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ],
#         [0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ],
#         [0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ],
#         ...,
#         [0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ],
#         [0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ],
#         [0.22391215, 0.23473228, 0.2344807 , ..., 0.21792017, 0.06511752,
#          0.0003167 ]]), memmap([[0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019],
#         [0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019],
#         [0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019],
#         ...,
#         [0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019],
#         [0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019],
#         [0.01465313, 0.01418297, 0.01470302, ..., 0.00329569, 0.00172642,
#          0.00033019]]), memmap([[0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032851],
#         [0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032851],
#         [0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032851],
#         ...,
#         [0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032851],
#         [0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032851],
#         [0.0124159 , 0.01253421, 0.01314193, ..., 0.09413476, 0.02250291,
#          0.00032851]]), memmap([[0.19544716, 0.18011644, 0.1924265 , ..., 0.18268867, 0.10586399,
#          0.00234728],
#         [0.19544716, 0.18011644, 0.1924265 , ..., 0.18268867, 0.10586399,
#          0.00234728],
#         [0.19544716, 0.18011644, 0.1924265 , ..., 0.18268867, 0.10586399,
#          0.00234728],
#         ...,
#         [0.19544716, 0.18011644, 0.1924265 , ..., 0.18268867, 0.10586399,
#          0.00234728],
#         [0.19544716, 0.18011644, 0.1924265 , ..., 0.18268867, 0.10586399,
#          0.00234728],
#         [0.19544716, 0.18011644, 0.1924265 , ..., 0.18268867, 0.10586399,
#          0.00234728]]), memmap([[0.21234749, 0.22403056, 0.23366935, ..., 0.22706366, 0.20008084,
#          0.01054985],
#         [0.21234749, 0.22403056, 0.23366935, ..., 0.22706366, 0.20008084,
#          0.01054985],
#         [0.21234749, 0.22403056, 0.23366935, ..., 0.22706366, 0.20008084,
#          0.01054985],
#         ...,
#         [0.21234749, 0.22403056, 0.23366935, ..., 0.22706366, 0.20008084,
#          0.01054985],
#         [0.21234749, 0.22403056, 0.23366935, ..., 0.22706366, 0.20008084,
#          0.01054985],
#         [0.21234749, 0.22403056, 0.23366935, ..., 0.22706366, 0.20008084,
#          0.01054985]]), memmap([[0.17727277, 0.17543582, 0.18217588, ..., 0.16713456, 0.08700726,
#          0.00096636],
#         [0.17727277, 0.17543582, 0.18217588, ..., 0.16713456, 0.08700726,
#          0.00096636],
#          0.00212373],
#         [0.24117295, 0.24163353, 0.23105744, ..., 0.21655965, 0.1268834 ,
#          0.00212373]]), memmap([[0.23893308, 0.23257667, 0.23728648, ..., 0.22969603, 0.15541276,
#          0.00502991],
#         [0.23893308, 0.23257667, 0.23728648, ..., 0.22969603, 0.15541276,
#          0.00502991],
#         [0.23893308, 0.23257667, 0.23728648, ..., 0.22969603, 0.15541276,
#          0.00502991],
#         ...,
#         [0.23893308, 0.23257667, 0.23728648, ..., 0.22969603, 0.15541276,
#          0.00502991],
#         [0.23893308, 0.23257667, 0.23728648, ..., 0.22969603, 0.15541276,
#          0.00502991],
#         [0.23893308, 0.23257667, 0.23728648, ..., 0.22969603, 0.15541276,
#          0.00502991]]), memmap([[0.30641476, 0.29409948, 0.30036226, ..., 0.23735658, 0.15238916,
#          0.00384993],
#         [0.30641476, 0.29409948, 0.30036226, ..., 0.23735658, 0.15238916,
#          0.00384993],
#         [0.30641476, 0.29409948, 0.30036226, ..., 0.23735658, 0.15238916,
#          0.00384993],
#         ...,
#         [0.30641476, 0.29409948, 0.30036226, ..., 0.23735658, 0.15238916,
#          0.00384993],
#         [0.30641476, 0.29409948, 0.30036226, ..., 0.23735658, 0.15238916,
#          0.00384993],
#         [0.30641476, 0.29409948, 0.30036226, ..., 0.23735658, 0.15238916,
#          0.00384993]]), memmap([[0.258655  , 0.25505244, 0.23293056, ..., 0.23868691, 0.12099474,
#          0.00102406],
#         [0.258655  , 0.25505244, 0.23293056, ..., 0.23868691, 0.12099474,
#          0.00102406],
#         [0.258655  , 0.25505244, 0.23293056, ..., 0.23868691, 0.12099474,
#          0.00102406],
#         ...,
#         [0.258655  , 0.25505244, 0.23293056, ..., 0.23868691, 0.12099474,
#          0.00102406],
#         [0.258655  , 0.25505244, 0.23293056, ..., 0.23868691, 0.12099474,
#          0.00102406],
#         [0.258655  , 0.25505244, 0.23293056, ..., 0.23868691, 0.12099474,
#          0.00102406]]), memmap([[0.21897976, 0.26337841, 0.25917364, ..., 0.16799034, 0.08071212,
#          0.00060947],
#         [0.21897976, 0.26337841, 0.25917364, ..., 0.16799034, 0.08071212,
#          0.00060947],
#         [0.21897976, 0.26337841, 0.25917364, ..., 0.16799034, 0.08071212,
#          0.00060947],
#         ...,
#         [0.21897976, 0.26337841, 0.25917364, ..., 0.16799034, 0.08071212,
#          0.00060947],
#         [0.21897976, 0.26337841, 0.25917364, ..., 0.16799034, 0.08071212,
#          0.00060947],
#         [0.21897976, 0.26337841, 0.25917364, ..., 0.16799034, 0.08071212,
#          0.00060947]]))

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import nibabel as nib
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Paths
base_dir = '/content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/'
groups = ['subacute', 'healthy', 'chronic']

# Function to load and preprocess MRI data
def load_and_process_mri(file_path):
    try:
        img = nib.load(file_path)
        img_data = img.get_fdata()
        img_data = (img_data - np.min(img_data)) / (np.max(img_data) - np.min(img_data))  # Normalize
        # Resize to target size if necessary
        target_size = (128, 128, 128)
        print(f"Original shape: {img_data.shape}")
        if img_data.shape != target_size:
            factors = [t / s for s, t in zip(img_data.shape, target_size)]
            img_data = zoom(img_data, factors, order=1)  # Resize
        return img_data
    except Exception as e:
        print(f"Error loading or processing {file_path}: {e}")
        return None

def data_generator(file_paths, labels, batch_size):
    while True:
        # Shuffle file paths and labels
        indices = np.arange(len(file_paths))
        np.random.shuffle(indices)
        file_paths = [file_paths[i] for i in indices]
        labels = [labels[i] for i in indices]

        # Yield batches
        for start in range(0, len(file_paths), batch_size):
            end = min(start + batch_size, len(file_paths))
            batch_file_paths = file_paths[start:end]
            batch_labels = labels[start:end]

            batch_images = []
            for file_path in batch_file_paths:
                img_data = load_and_process_mri(file_path)
                if img_data is not None:
                    batch_images.append(img_data)

            batch_images = np.array(batch_images)
            batch_labels = np.array(batch_labels)

            yield batch_images, batch_labels

def create_dataset_from_directory(directory, split_name, batch_size):
    file_paths = []
    labels = []
    for group in groups:
        split_dir = os.path.join(directory, group, split_name)
        print(f"Processing split directory: {split_dir}")
        for file_name in os.listdir(split_dir):
            if file_name.endswith('.nii'):
                file_paths.append(os.path.join(split_dir, file_name))
                labels.append(group)

    labels = [groups.index(label) for label in labels]

    dataset = tf.data.Dataset.from_generator(
        lambda: data_generator(file_paths, labels, batch_size),
        output_signature=(
            tf.TensorSpec(shape=(None, 128, 128, 128), dtype=tf.float32),
            tf.TensorSpec(shape=(None,), dtype=tf.int64)
        )
    )

    return dataset

# Create datasets
train_ds = create_dataset_from_directory(base_dir, 'train', batch_size=32)
val_ds = create_dataset_from_directory(base_dir, 'val', batch_size=32)
test_ds = create_dataset_from_directory(base_dir, 'test', batch_size=32)

# Define the 3D CNN model
model = models.Sequential([
    layers.Conv3D(32, (3, 3, 3), activation='relu', input_shape=(128, 128, 128, 1)),
    layers.MaxPooling3D((2, 2, 2)),
    layers.Conv3D(64, (3, 3, 3), activation='relu'),
    layers.MaxPooling3D((2, 2, 2)),
    layers.Conv3D(128, (3, 3, 3), activation='relu'),
    layers.MaxPooling3D((2, 2, 2)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(len(groups), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    steps_per_epoch=100,  # Adjust based on your dataset size
    validation_steps=10  # Adjust based on your dataset size
)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_ds, steps=10)  # Adjust steps based on your dataset size
print(f"Test Accuracy: {test_acc}")

# Predict on test set
y_true = []
y_pred = []

for images, labels in test_ds:
    predictions = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))

# Calculate and plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=groups, yticklabels=groups)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
print(classification_report(y_true, y_pred, target_names=groups))
# Out:
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/val
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/val
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/val
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/test
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/test
# Processing split directory: /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/test
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train/subacute_sub-002_ses-visit4_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-088_ses-visit4_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train/subacute_sub-020_ses-visit3_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-085_ses-visit4_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train/chronic_sub-105_ses-visit2_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-089_ses-visit4_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train/chronic_sub-112_ses-visit3_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train/chronic_sub-098_ses-visit1_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train/subacute_sub-058_ses-visit3_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-079_ses-visit4_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-083_ses-visit1_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train/subacute_sub-014_ses-visit3_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train/subacute_sub-060_ses-visit5_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train/subacute_sub-043_ses-visit3_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train/chronic_sub-112_ses-visit4_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-080_ses-visit4_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-082_ses-visit2_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-082_ses-visit3_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-085_ses-visit2_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train/chronic_sub-097_ses-visit4_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-071_ses-visit3_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/subacute/train/subacute_sub-035_ses-visit1_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train/chronic_sub-115_ses-visit4_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-087_ses-visit3_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-072_ses-visit2_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-071_ses-visit4_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-084_ses-visit1_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train/chronic_sub-119_ses-visit2_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train/chronic_sub-115_ses-visit1_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/chronic/train/chronic_sub-109_ses-visit2_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-076_ses-visit2_T1w.nii: name 'zoom' is not defined
# Original shape: (128, 128)
# Error loading or processing /content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/healthy/train/healthy_sub-084_ses-visit2_T1w.nii: name 'zoom' is not defined
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-51-87f36f5b7b71> in <cell line: 103>()
#     101
#     102 # Train the model
# --> 103 history = model.fit(
#     104     train_ds,
#     105     validation_data=val_ds,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node PyFunc defined at (most recent call last):
# <stack traces unavailable>
# TypeError: `generator` yielded an element of shape (0,) where an element of shape (None, 128, 128, 128) was expected.
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/script_ops.py", line 270, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/from_generator_op.py", line 235, in generator_py_func
#     raise TypeError(
#
# TypeError: `generator` yielded an element of shape (0,) where an element of shape (None, 128, 128, 128) was expected.
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]] [Op:__inference_one_step_on_iterator_6232]

# %%
import os
import numpy as np
import nibabel as nib
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# Define the 3D-CNN model function
def build_3d_cnn(input_shape, num_classes):
    inputs = tf.keras.Input(shape=input_shape)

    # Encoder
    x = Conv3D(32, kernel_size=(3, 3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling3D(pool_size=(2, 2, 2))(x)
    x = BatchNormalization()(x)

    x = Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same')(x)
    x = MaxPooling3D(pool_size=(2, 2, 2))(x)
    x = BatchNormalization()(x)

    x = Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same')(x)
    x = MaxPooling3D(pool_size=(2, 2, 2))(x)
    x = BatchNormalization()(x)

    x = Conv3D(256, kernel_size=(3, 3, 3), activation='relu', padding='same')(x)
    x = MaxPooling3D(pool_size=(2, 2, 2))(x)
    x = BatchNormalization()(x)

    # Flatten and dense layers
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=[inputs], outputs=[outputs])

    return model

# Paths
base_dir = '/content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/'

splits = ['train', 'val', 'test']
groups = ['healthy', 'chronic', 'subacute']

def load_mri_data(base_dir, groups, splits):
    data = []
    labels = []
    for group_idx, group in enumerate(groups):
        for split in splits:
            split_dir = os.path.join(base_dir, group, split)
            for file_name in os.listdir(split_dir):
                if file_name.endswith('.nii'):
                    file_path = os.path.join(split_dir, file_name)
                    mri_image_nii = nib.load(file_path)
                    mri_image = mri_image_nii.get_fdata()
                    data.append(mri_image)
                    labels.append(group_idx)
    return np.array(data), np.array(labels)

# Load data
data, labels = load_mri_data(base_dir, groups, splits)

# Split data into train, validation, and test sets
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)
val_data, test_data, val_labels, test_labels = train_test_split(test_data, test_labels, test_size=0.5, random_state=42, stratify=test_labels)

# Normalize data
train_data = (train_data - np.min(train_data)) / (np.max(train_data) - np.min(train_data))
val_data = (val_data - np.min(val_data)) / (np.max(val_data) - np.min(val_data))
test_data = (test_data - np.min(test_data)) / (np.max(test_data) - np.min(test_data))

# Add a channel dimension
train_data = np.expand_dims(train_data, axis=-1)
val_data = np.expand_dims(val_data, axis=-1)
test_data = np.expand_dims(test_data, axis=-1)

# Convert labels to categorical
train_labels = to_categorical(train_labels, num_classes=len(groups))
val_labels = to_categorical(val_labels, num_classes=len(groups))
test_labels = to_categorical(test_labels, num_classes=len(groups))

# Define and compile the model
input_shape = (128, 128, 128, 1)  # Adjust based on your input shape
num_classes = len(groups)
model = build_3d_cnn(input_shape, num_classes)
optimizer = Adam(learning_rate=1e-4)  # Adjust learning rate as needed
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, train_labels, epochs=20, batch_size=2, validation_data=(val_data, val_labels))

# Evaluate the model
test_predictions = model.predict(test_data)
test_labels_pred = np.argmax(test_predictions, axis=1)
test_labels_true = np.argmax(test_labels, axis=1)

# Confusion Matrix
cm = confusion_matrix(test_labels_true, test_labels_pred)
print('Confusion Matrix:\n', cm)

# F1 Score
f1 = f1_score(test_labels_true, test_labels_pred, average='weighted')
print('F1 Score:', f1)

# Classification Report
report = classification_report(test_labels_true, test_labels_pred, target_names=groups)
print('Classification Report:\n', report)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=groups, yticklabels=groups)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Epoch 1/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 899s 9s/step - accuracy: 0.4232 - loss: 13.0518 - val_accuracy: 0.3333 - val_loss: 6.3148
# Epoch 2/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 868s 9s/step - accuracy: 0.4268 - loss: 19.9866 - val_accuracy: 0.3333 - val_loss: 10.8895
# Epoch 3/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 891s 9s/step - accuracy: 0.4588 - loss: 10.8246 - val_accuracy: 0.3333 - val_loss: 9.1533
# Epoch 4/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 882s 9s/step - accuracy: 0.4920 - loss: 13.6014 - val_accuracy: 0.3333 - val_loss: 8.7125
# Epoch 5/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 872s 9s/step - accuracy: 0.5503 - loss: 5.8438 - val_accuracy: 0.3333 - val_loss: 11.3133
# Epoch 6/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 864s 9s/step - accuracy: 0.5939 - loss: 3.4216 - val_accuracy: 0.4167 - val_loss: 9.4644
# Epoch 7/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 870s 9s/step - accuracy: 0.5335 - loss: 1.9481 - val_accuracy: 0.3333 - val_loss: 1.2279
# Epoch 8/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 870s 9s/step - accuracy: 0.5450 - loss: 0.9819 - val_accuracy: 0.4167 - val_loss: 1.4573
# Epoch 9/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 870s 9s/step - accuracy: 0.5418 - loss: 0.9005 - val_accuracy: 0.6667 - val_loss: 0.9230
# Epoch 10/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 868s 9s/step - accuracy: 0.5901 - loss: 0.7781 - val_accuracy: 0.7083 - val_loss: 0.9157
# Epoch 11/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 871s 9s/step - accuracy: 0.6717 - loss: 0.8220 - val_accuracy: 0.7500 - val_loss: 0.7610
# Epoch 12/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 872s 9s/step - accuracy: 0.6205 - loss: 1.1157 - val_accuracy: 0.5000 - val_loss: 0.9224
# Epoch 13/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 877s 9s/step - accuracy: 0.5575 - loss: 0.8454 - val_accuracy: 0.5417 - val_loss: 0.8782
# Epoch 14/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 870s 9s/step - accuracy: 0.6042 - loss: 0.7920 - val_accuracy: 0.6667 - val_loss: 0.9512
# Epoch 15/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 868s 9s/step - accuracy: 0.5259 - loss: 0.8366 - val_accuracy: 0.5000 - val_loss: 1.0694
# Epoch 16/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 869s 9s/step - accuracy: 0.5982 - loss: 0.7855 - val_accuracy: 0.4167 - val_loss: 1.3784
# Epoch 17/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 871s 9s/step - accuracy: 0.7118 - loss: 0.6719 - val_accuracy: 0.6250 - val_loss: 1.1314
# Epoch 18/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 874s 9s/step - accuracy: 0.6976 - loss: 0.7057 - val_accuracy: 0.6250 - val_loss: 1.2646
# Epoch 19/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 867s 9s/step - accuracy: 0.6066 - loss: 0.7235 - val_accuracy: 0.6250 - val_loss: 1.2650
# Epoch 20/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 875s 9s/step - accuracy: 0.6651 - loss: 0.7759 - val_accuracy: 0.3750 - val_loss: 1.7560
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# Confusion Matrix:
#  [[3 0 5]
#  [3 1 4]
#  [1 0 7]]
# F1 Score: 0.4018518518518519
# Classification Report:
#                precision    recall  f1-score   support
#
#      healthy       0.43      0.38      0.40         8
#      chronic       1.00      0.12      0.22         8
#     subacute       0.44      0.88      0.58         8
#
#     accuracy                           0.46        24
#    macro avg       0.62      0.46      0.40        24
# weighted avg       0.62      0.46      0.40        24

# %%
model.save('3dcnn_model_3dMRIs.keras')

# %%
import os
import numpy as np
import nibabel as nib
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization, Add, Activation, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# Define the residual block for ResNet
def residual_block(x, filters, kernel_size=(3, 3, 3), stride=(1, 1, 1)):
    shortcut = x
    x = Conv3D(filters, kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv3D(filters, kernel_size, padding='same')(x)
    x = BatchNormalization()(x)

    if x.shape[-1] != shortcut.shape[-1]:
        shortcut = Conv3D(filters, (1, 1, 1), strides=stride, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# Define the 3D ResNet model
def build_3d_resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Initial Conv Layer
    x = Conv3D(64, kernel_size=(7, 7, 7), strides=(2, 2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling3D(pool_size=(3, 3, 3))(x)

    # Residual blocks
    x = residual_block(x, 64)
    x = residual_block(x, 64)
    x = residual_block(x, 128, stride=(2, 2, 2))  # Downsampling
    x = residual_block(x, 128)
    x = residual_block(x, 256, stride=(2, 2, 2))  # Downsampling
    x = residual_block(x, 256)

    # Global Average Pooling and dense layers
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Paths
base_dir = '/content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/'

splits = ['train', 'val', 'test']
groups = ['healthy', 'chronic', 'subacute']

def load_mri_data(base_dir, groups, splits):
    data = []
    labels = []
    for group_idx, group in enumerate(groups):
        for split in splits:
            split_dir = os.path.join(base_dir, group, split)
            for file_name in os.listdir(split_dir):
                if file_name.endswith('.nii'):
                    file_path = os.path.join(split_dir, file_name)
                    mri_image_nii = nib.load(file_path)
                    mri_image = mri_image_nii.get_fdata()
                    data.append(mri_image)
                    labels.append(group_idx)
    return np.array(data), np.array(labels)

# Load data
data, labels = load_mri_data(base_dir, groups, splits)

# Split data into train, validation, and test sets
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)
val_data, test_data, val_labels, test_labels = train_test_split(test_data, test_labels, test_size=0.5, random_state=42, stratify=test_labels)

# Normalize data
train_data = (train_data - np.min(train_data)) / (np.max(train_data) - np.min(train_data))
val_data = (val_data - np.min(val_data)) / (np.max(val_data) - np.min(val_data))
test_data = (test_data - np.min(test_data)) / (np.max(test_data) - np.min(test_data))

# Add a channel dimension
train_data = np.expand_dims(train_data, axis=-1)
val_data = np.expand_dims(val_data, axis=-1)
test_data = np.expand_dims(test_data, axis=-1)

# Convert labels to categorical
train_labels = to_categorical(train_labels, num_classes=len(groups))
val_labels = to_categorical(val_labels, num_classes=len(groups))
test_labels = to_categorical(test_labels, num_classes=len(groups))

# Define and compile the model
input_shape = train_data.shape[1:]  # This should be (128, 128, 128, 1)
num_classes = len(groups)
model = build_3d_resnet(input_shape, num_classes)
optimizer = Adam(learning_rate=1e-4)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, train_labels, epochs=20, batch_size=2, validation_data=(val_data, val_labels))

# Evaluate the model
test_predictions = model.predict(test_data)
test_labels_pred = np.argmax(test_predictions, axis=1)
test_labels_true = np.argmax(test_labels, axis=1)

# Confusion Matrix
cm = confusion_matrix(test_labels_true, test_labels_pred)
print('Confusion Matrix:\n', cm)

# F1 Score
f1 = f1_score(test_labels_true, test_labels_pred, average='weighted')
print('F1 Score:', f1)

# Classification Report
report = classification_report(test_labels_true, test_labels_pred, target_names=groups)
print('Classification Report:\n', report)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=groups, yticklabels=groups)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Save the model
model.save('3d_resnet_model.keras')
# Out:
# Epoch 1/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 360s 4s/step - accuracy: 0.3895 - loss: 12.7333 - val_accuracy: 0.3333 - val_loss: 1.3226
# Epoch 2/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 333s 3s/step - accuracy: 0.4085 - loss: 1.9068 - val_accuracy: 0.3333 - val_loss: 1.2715
# Epoch 3/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 331s 3s/step - accuracy: 0.3828 - loss: 1.1418 - val_accuracy: 0.3333 - val_loss: 1.3296
# Epoch 4/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 349s 4s/step - accuracy: 0.4633 - loss: 1.0679 - val_accuracy: 0.3333 - val_loss: 1.3586
# Epoch 5/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.3735 - loss: 1.0385 - val_accuracy: 0.3333 - val_loss: 1.2774
# Epoch 6/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 335s 3s/step - accuracy: 0.5170 - loss: 1.0378 - val_accuracy: 0.3333 - val_loss: 1.2821
# Epoch 7/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 334s 3s/step - accuracy: 0.5159 - loss: 0.9517 - val_accuracy: 0.2917 - val_loss: 1.1020
# Epoch 8/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 330s 3s/step - accuracy: 0.4692 - loss: 0.9106 - val_accuracy: 0.3333 - val_loss: 1.0229
# Epoch 9/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 337s 4s/step - accuracy: 0.4637 - loss: 0.9533 - val_accuracy: 0.4167 - val_loss: 1.1613
# Epoch 10/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 332s 3s/step - accuracy: 0.4901 - loss: 1.0292 - val_accuracy: 0.3333 - val_loss: 1.0123
# Epoch 11/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 334s 3s/step - accuracy: 0.5021 - loss: 1.0216 - val_accuracy: 0.4167 - val_loss: 1.0521
# Epoch 12/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 333s 3s/step - accuracy: 0.4608 - loss: 0.9813 - val_accuracy: 0.3333 - val_loss: 1.2094
# Epoch 13/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 335s 3s/step - accuracy: 0.5008 - loss: 1.0310 - val_accuracy: 0.3750 - val_loss: 1.2181
# Epoch 14/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 333s 3s/step - accuracy: 0.4651 - loss: 0.9653 - val_accuracy: 0.6667 - val_loss: 1.0251
# Epoch 15/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 340s 4s/step - accuracy: 0.5075 - loss: 0.9970 - val_accuracy: 0.3750 - val_loss: 1.1215
# Epoch 16/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 336s 3s/step - accuracy: 0.5102 - loss: 0.9190 - val_accuracy: 0.3333 - val_loss: 1.0035
# Epoch 17/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 331s 3s/step - accuracy: 0.6279 - loss: 0.8578 - val_accuracy: 0.3750 - val_loss: 1.0813
# Epoch 18/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 337s 4s/step - accuracy: 0.5654 - loss: 0.8361 - val_accuracy: 0.4583 - val_loss: 1.0964
# Epoch 19/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 340s 4s/step - accuracy: 0.6531 - loss: 0.7808 - val_accuracy: 0.5417 - val_loss: 0.9763
# Epoch 20/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 350s 4s/step - accuracy: 0.5553 - loss: 0.9618 - val_accuracy: 0.4583 - val_loss: 1.0153
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# Confusion Matrix:
#  [[6 2 0]
#  [0 8 0]
#  [2 2 4]]
# F1 Score: 0.7388888888888889
# Classification Report:
#                precision    recall  f1-score   support
#
#      healthy       0.75      0.75      0.75         8
#      chronic       0.67      1.00      0.80         8
#     subacute       1.00      0.50      0.67         8
#
#     accuracy                           0.75        24
#    macro avg       0.81      0.75      0.74        24
# weighted avg       0.81      0.75      0.74        24

# %%
import os
import numpy as np
import nibabel as nib
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization, Add, Activation, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# Define the residual block for ResNet
def residual_block(x, filters, kernel_size=(3, 3, 3), stride=(1, 1, 1)):
    shortcut = x
    x = Conv3D(filters, kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv3D(filters, kernel_size, padding='same')(x)
    x = BatchNormalization()(x)

    if x.shape[-1] != shortcut.shape[-1]:
        shortcut = Conv3D(filters, (1, 1, 1), strides=stride, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# Define the 3D ResNet model
def build_3d_resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Initial Conv Layer
    x = Conv3D(64, kernel_size=(7, 7, 7), strides=(2, 2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling3D(pool_size=(3, 3, 3))(x)

    # Residual blocks
    x = residual_block(x, 64)
    x = residual_block(x, 64)
    x = residual_block(x, 128, stride=(2, 2, 2))  # Downsampling
    x = residual_block(x, 128)
    x = residual_block(x, 256, stride=(2, 2, 2))  # Downsampling
    x = residual_block(x, 256)

    # Global Average Pooling and dense layers
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Paths
base_dir = '/content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/'

splits = ['train', 'val', 'test']
groups = ['healthy', 'chronic', 'subacute']

def load_mri_data(base_dir, groups, splits):
    data = []
    labels = []
    for group_idx, group in enumerate(groups):
        for split in splits:
            split_dir = os.path.join(base_dir, group, split)
            for file_name in os.listdir(split_dir):
                if file_name.endswith('.nii'):
                    file_path = os.path.join(split_dir, file_name)
                    mri_image_nii = nib.load(file_path)
                    mri_image = mri_image_nii.get_fdata()
                    data.append(mri_image)
                    labels.append(group_idx)
    return np.array(data), np.array(labels)

# Load data
data, labels = load_mri_data(base_dir, groups, splits)

# Split data into train, validation, and test sets
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)
val_data, test_data, val_labels, test_labels = train_test_split(test_data, test_labels, test_size=0.5, random_state=42, stratify=test_labels)

# Normalize data
train_data = (train_data - np.min(train_data)) / (np.max(train_data) - np.min(train_data))
val_data = (val_data - np.min(val_data)) / (np.max(val_data) - np.min(val_data))
test_data = (test_data - np.min(test_data)) / (np.max(test_data) - np.min(test_data))

# Add a channel dimension
train_data = np.expand_dims(train_data, axis=-1)
val_data = np.expand_dims(val_data, axis=-1)
test_data = np.expand_dims(test_data, axis=-1)

# Convert labels to categorical
train_labels = to_categorical(train_labels, num_classes=len(groups))
val_labels = to_categorical(val_labels, num_classes=len(groups))
test_labels = to_categorical(test_labels, num_classes=len(groups))

# Define and compile the model
input_shape = train_data.shape[1:]  # This should be (128, 128, 128, 1)
num_classes = len(groups)
model = build_3d_resnet(input_shape, num_classes)
optimizer = Adam(learning_rate=1e-4)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, train_labels, epochs=30, batch_size=6, validation_data=(val_data, val_labels))

# Evaluate the model
test_predictions = model.predict(test_data)
test_labels_pred = np.argmax(test_predictions, axis=1)
test_labels_true = np.argmax(test_labels, axis=1)

# Confusion Matrix
cm = confusion_matrix(test_labels_true, test_labels_pred)
print('Confusion Matrix:\n', cm)

# F1 Score
f1 = f1_score(test_labels_true, test_labels_pred, average='weighted')
print('F1 Score:', f1)

# Classification Report
report = classification_report(test_labels_true, test_labels_pred, target_names=groups)
print('Classification Report:\n', report)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=groups, yticklabels=groups)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

#
30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 292s 9s/step - accuracy: 0.9988 - loss: 0.0071 - val_accuracy: 0.7083 - val_loss: 0.8955
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 292s 9s/step - accuracy: 0.9843 - loss: 0.0554 - val_accuracy: 0.3333 - val_loss: 4.4381
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 295s 9s/step - accuracy: 0.8848 - loss: 0.2943 - val_accuracy: 0.3750 - val_loss: 3.6936
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# Confusion Matrix:
#  [[1 0 7]
#  [0 0 8]
#  [0 0 8]]
# F1 Score: 0.24611708482676223
# Classification Report:
#                precision    recall  f1-score   support
#
#      healthy       1.00      0.12      0.22         8
#      chronic       0.00      0.00      0.00         8
#     subacute       0.35      1.00      0.52         8
#
#     accuracy                           0.38        24
#    macro avg       0.45      0.38      0.25        24
# weighted avg       0.45      0.38      0.25        24
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import numpy as np
import nibabel as nib
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization, Add, Activation, Input, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# Define the Dense Block for DenseNet
def dense_block(x, num_layers, growth_rate):
    for _ in range(num_layers):
        x = Conv3D(growth_rate, (3, 3, 3), padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Concatenate()([x, x])
    return x

# Define the Transition Layer for DenseNet
def transition_layer(x, reduction):
    x = Conv3D(int(x.shape[-1] * reduction), (1, 1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling3D(pool_size=(2, 2, 2))(x)
    return x

# Define the 3D DenseNet model
def build_3d_densenet(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Initial Conv Layer
    x = Conv3D(64, (7, 7, 7), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling3D(pool_size=(2, 2, 2))(x)

    # Dense Blocks
    x = dense_block(x, num_layers=4, growth_rate=32)
    x = transition_layer(x, reduction=0.5)
    x = dense_block(x, num_layers=4, growth_rate=32)
    x = transition_layer(x, reduction=0.5)
    x = dense_block(x, num_layers=4, growth_rate=32)

    # Global Average Pooling and dense layers
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Paths
base_dir = '/content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/'

splits = ['train', 'val', 'test']
groups = ['healthy', 'chronic', 'subacute']

def load_mri_data(base_dir, groups, splits):
    data = []
    labels = []
    for group_idx, group in enumerate(groups):
        for split in splits:
            split_dir = os.path.join(base_dir, group, split)
            for file_name in os.listdir(split_dir):
                if file_name.endswith('.nii'):
                    file_path = os.path.join(split_dir, file_name)
                    mri_image_nii = nib.load(file_path)
                    mri_image = mri_image_nii.get_fdata()
                    data.append(mri_image)
                    labels.append(group_idx)
    return np.array(data), np.array(labels)

# Load data
data, labels = load_mri_data(base_dir, groups, splits)

# Split data into train, validation, and test sets
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)
val_data, test_data, val_labels, test_labels = train_test_split(test_data, test_labels, test_size=0.5, random_state=42, stratify=test_labels)

# Normalize data
train_data = (train_data - np.min(train_data)) / (np.max(train_data) - np.min(train_data))
val_data = (val_data - np.min(val_data)) / (np.max(val_data) - np.min(val_data))
test_data = (test_data - np.min(test_data)) / (np.max(test_data) - np.min(test_data))

# Add a channel dimension
train_data = np.expand_dims(train_data, axis=-1)
val_data = np.expand_dims(val_data, axis=-1)
test_data = np.expand_dims(test_data, axis=-1)

# Convert labels to categorical
train_labels = to_categorical(train_labels, num_classes=len(groups))
val_labels = to_categorical(val_labels, num_classes=len(groups))
test_labels = to_categorical(test_labels, num_classes=len(groups))

# Define and compile the model
input_shape = train_data.shape[1:]  # This should be (128, 128, 128, 1)
num_classes = len(groups)
model = build_3d_densenet(input_shape, num_classes)
optimizer = Adam(learning_rate=1e-4)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, train_labels, epochs=8, batch_size=4, validation_data=(val_data, val_labels))

# Evaluate the model
test_predictions = model.predict(test_data)
test_labels_pred = np.argmax(test_predictions, axis=1)
test_labels_true = np.argmax(test_labels, axis=1)

# Confusion Matrix
cm = confusion_matrix(test_labels_true, test_labels_pred)
print('Confusion Matrix:\n', cm)

# F1 Score
f1 = f1_score(test_labels_true, test_labels_pred, average='weighted')
print('F1 Score:', f1)

# Classification Report
report = classification_report(test_labels_true, test_labels_pred, target_names=groups)
print('Classification Report:\n', report)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=groups, yticklabels=groups)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Save the model
model.save('/content/drive/My Drive/ChronicAI/models/3d_densenet_model_8_epochs.keras')
# Out:
# Epoch 1/8
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5396s 112s/step - accuracy: 0.4209 - loss: 15.3441 - val_accuracy: 0.3333 - val_loss: 6.3375
# Epoch 2/8
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5390s 112s/step - accuracy: 0.4626 - loss: 10.0263 - val_accuracy: 0.3333 - val_loss: 5.1779
# Epoch 3/8
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5300s 110s/step - accuracy: 0.4324 - loss: 3.4694 - val_accuracy: 0.3333 - val_loss: 2.3719
# Epoch 4/8
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5388s 112s/step - accuracy: 0.4710 - loss: 1.1926 - val_accuracy: 0.3333 - val_loss: 2.0507
# Epoch 5/8
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5315s 111s/step - accuracy: 0.5747 - loss: 0.9437 - val_accuracy: 0.3333 - val_loss: 2.9045
# Epoch 6/8
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5277s 110s/step - accuracy: 0.5893 - loss: 0.8285 - val_accuracy: 0.3333 - val_loss: 3.6565
# Epoch 7/8
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5316s 111s/step - accuracy: 0.6046 - loss: 0.8206 - val_accuracy: 0.3333 - val_loss: 4.1335
# Epoch 8/8
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5288s 110s/step - accuracy: 0.6840 - loss: 0.7155 - val_accuracy: 0.3333 - val_loss: 4.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 98s 98s/step
# Confusion Matrix:
#  [[0 0 8]
#  [0 0 8]
#  [0 0 8]]
# F1 Score: 0.16666666666666666
# Classification Report:
#                precision    recall  f1-score   support
#
#      healthy       0.00      0.00      0.00         8
#      chronic       0.00      0.00      0.00         8
#     subacute       0.33      1.00      0.50         8
#
#     accuracy                           0.33        24
#    macro avg       0.11      0.33      0.17        24
# weighted avg       0.11      0.33      0.17        24
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import numpy as np
import nibabel as nib
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization, Add, Activation, Input, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# Define the Dense Block for DenseNet
def dense_block(x, num_layers, growth_rate):
    for _ in range(num_layers):
        conv = Conv3D(growth_rate, (3, 3, 3), padding='same')(x)
        conv = BatchNormalization()(conv)
        conv = Activation('relu')(conv)
        x = Concatenate()([x, conv])
    return x

# Define the Transition Layer for DenseNet
def transition_layer(x, reduction):
    x = Conv3D(int(x.shape[-1] * reduction), (1, 1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling3D(pool_size=(2, 2, 2))(x)
    return x

# Define the 3D DenseNet model
def build_3d_densenet(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Initial Conv Layer
    x = Conv3D(64, (7, 7, 7), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling3D(pool_size=(2, 2, 2))(x)

    # Dense Blocks
    x = dense_block(x, num_layers=4, growth_rate=32)
    x = transition_layer(x, reduction=0.5)
    x = dense_block(x, num_layers=4, growth_rate=32)
    x = transition_layer(x, reduction=0.5)
    x = dense_block(x, num_layers=4, growth_rate=32)

    # Global Average Pooling and dense layers
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Paths
base_dir = '/content/drive/My Drive/ChronicAI/dataset/TrainTestValSplit/'

splits = ['train', 'val', 'test']
groups = ['healthy', 'chronic', 'subacute']

def load_mri_data(base_dir, groups, splits):
    data = []
    labels = []
    for group_idx, group in enumerate(groups):
        for split in splits:
            split_dir = os.path.join(base_dir, group, split)
            for file_name in os.listdir(split_dir):
                if file_name.endswith('.nii'):
                    file_path = os.path.join(split_dir, file_name)
                    mri_image_nii = nib.load(file_path)
                    mri_image = mri_image_nii.get_fdata()
                    data.append(mri_image)
                    labels.append(group_idx)
    return np.array(data), np.array(labels)

# Load data
data, labels = load_mri_data(base_dir, groups, splits)

# Split data into train, validation, and test sets
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)
val_data, test_data, val_labels, test_labels = train_test_split(test_data, test_labels, test_size=0.5, random_state=42, stratify=test_labels)

# Normalize data
train_data = (train_data - np.min(train_data)) / (np.max(train_data) - np.min(train_data))
val_data = (val_data - np.min(val_data)) / (np.max(val_data) - np.min(val_data))
test_data = (test_data - np.min(test_data)) / (np.max(test_data) - np.min(test_data))

# Add a channel dimension
train_data = np.expand_dims(train_data, axis=-1)
val_data = np.expand_dims(val_data, axis=-1)
test_data = np.expand_dims(test_data, axis=-1)

# Convert labels to categorical
train_labels = to_categorical(train_labels, num_classes=len(groups))
val_labels = to_categorical(val_labels, num_classes=len(groups))
test_labels = to_categorical(test_labels, num_classes=len(groups))

# Define and compile the model
input_shape = train_data.shape[1:]  # This should be (128, 128, 128, 1)
num_classes = len(groups)
model = build_3d_densenet(input_shape, num_classes)
optimizer = Adam(learning_rate=1e-4)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, train_labels, epochs=20, batch_size=4, validation_data=(val_data, val_labels))

# Evaluate the model
test_predictions = model.predict(test_data)
test_labels_pred = np.argmax(test_predictions, axis=1)
test_labels_true = np.argmax(test_labels, axis=1)

# Confusion Matrix
cm = confusion_matrix(test_labels_true, test_labels_pred)
print('Confusion Matrix:\n', cm)

# F1 Score
f1 = f1_score(test_labels_true, test_labels_pred, average='weighted')
print('F1 Score:', f1)

# Classification Report
report = classification_report(test_labels_true, test_labels_pred, target_names=groups)
print('Classification Report:\n', report)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=groups, yticklabels=groups)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Save the model
model.save('/content/drive/My Drive/ChronicAI/models/3d_densenet_model_20_epochs.keras')
# Out:
# Epoch 1/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4250s 88s/step - accuracy: 0.4067 - loss: 91.7777 - val_accuracy: 0.3333 - val_loss: 37.0322
# Epoch 2/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4144s 86s/step - accuracy: 0.4643 - loss: 49.1428 - val_accuracy: 0.3333 - val_loss: 16.6776
# Epoch 3/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4181s 87s/step - accuracy: 0.4055 - loss: 20.0539 - val_accuracy: 0.3333 - val_loss: 12.9535
# Epoch 4/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4118s 86s/step - accuracy: 0.3821 - loss: 9.4680 - val_accuracy: 0.3333 - val_loss: 7.7062
# Epoch 5/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4071s 85s/step - accuracy: 0.4559 - loss: 1.0855 - val_accuracy: 0.3333 - val_loss: 6.0525
# Epoch 6/20
# 45/48 ━━━━━━━━━━━━━━━━━━━━ 4:11 84s/step - accuracy: 0.3713 - loss: 1.0456
