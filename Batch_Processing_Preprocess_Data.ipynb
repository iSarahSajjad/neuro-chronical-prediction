# %% [markdown]
# <a href="https://colab.research.google.com/github/iSarahSajjad/neuro-chronical-prediction/blob/Models/Batch_Processing_Preprocess_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import nibabel as nib
from skimage.transform import resize
import pickle

# Load participant information
participant_df = pd.read_csv('/content/drive/My Drive/ChronicAI/dataset/participants.tsv', sep='\t')

# Convert labels to numerical values
label_mapping = {'chronic': 0, 'healthy': 1, 'subacute': 2}

# Parameters for batch processing
batch_size = 32  # Adjust based on available RAM
num_samples = len(participant_df)
num_batches = int(np.ceil(num_samples / batch_size))

# Directory to store preprocessed batches
output_dir = '/content/drive/My Drive/ChronicAI/dataset/preprocessed_batches'
os.makedirs(output_dir, exist_ok=True)

target_shape = None  # Initialize target shape for resizing

def preprocess_and_save_batch(batch_idx, batch_size):
    global target_shape  # Access the global target_shape variable
    start_idx = batch_idx * batch_size
    end_idx = min((batch_idx + 1) * batch_size, num_samples)

    batch_data = []
    batch_labels = []

    for index in range(start_idx, end_idx):
        row = participant_df.iloc[index]
        participant_id = row['participant_id']
        folder_name = participant_id
        for visit in range(1, 6):
            mri_path = f'/content/drive/My Drive/ChronicAI/dataset/{folder_name}/ses-visit{visit}/anat/{folder_name}_ses-visit{visit}_T1w.nii'
            if os.path.exists(mri_path):
                img = nib.load(mri_path)
                img_data = img.get_fdata()

                if target_shape is None:
                    target_shape = img_data.shape

                img_data_resized = resize(img_data, target_shape, order=1, preserve_range=True)

                batch_data.append(img_data_resized)
                batch_labels.append(row['group'])
            else:
                print(f"Warning: MRI file not found at {mri_path}")

    batch_data = np.stack(batch_data)
    batch_data = (batch_data - np.min(batch_data)) / (np.max(batch_data) - np.min(batch_data))
    batch_labels = np.array([label_mapping[label] for label in batch_labels])

    # Save batch data and labels
    batch_filename = os.path.join(output_dir, f'batch_{batch_idx}.pkl')
    with open(batch_filename, 'wb') as f:
        pickle.dump((batch_data, batch_labels), f)

# Process data in batches and save to disk
for batch_idx in range(num_batches):
    preprocess_and_save_batch(batch_idx, batch_size)
    print(f"Batch {batch_idx} processed and saved.")

print("All batches preprocessed and saved.")
# Out:
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-001/ses-visit3/anat/sub-001_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-002/ses-visit5/anat/sub-002_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-003/ses-visit2/anat/sub-003_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-003/ses-visit5/anat/sub-003_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-004/ses-visit5/anat/sub-004_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-005/ses-visit5/anat/sub-005_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-007/ses-visit4/anat/sub-007_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-007/ses-visit5/anat/sub-007_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-009/ses-visit2/anat/sub-009_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-009/ses-visit4/anat/sub-009_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit1/anat/sub-010_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit2/anat/sub-010_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit3/anat/sub-010_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-010/ses-visit5/anat/sub-010_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-011/ses-visit1/anat/sub-011_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-011/ses-visit4/anat/sub-011_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-011/ses-visit5/anat/sub-011_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-014/ses-visit1/anat/sub-014_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-015/ses-visit5/anat/sub-015_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-018/ses-visit3/anat/sub-018_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-018/ses-visit5/anat/sub-018_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-019/ses-visit1/anat/sub-019_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-019/ses-visit4/anat/sub-019_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-020/ses-visit5/anat/sub-020_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-visit1/anat/sub-021_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-visit2/anat/sub-021_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-visit4/anat/sub-021_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-021/ses-visit5/anat/sub-021_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-022/ses-visit2/anat/sub-022_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-022/ses-visit5/anat/sub-022_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-023/ses-visit1/anat/sub-023_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-025/ses-visit1/anat/sub-025_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-025/ses-visit5/anat/sub-025_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-026/ses-visit5/anat/sub-026_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-027/ses-visit4/anat/sub-027_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-028/ses-visit5/anat/sub-028_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-029/ses-visit4/anat/sub-029_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-029/ses-visit5/anat/sub-029_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-030/ses-visit4/anat/sub-030_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-031/ses-visit3/anat/sub-031_ses-visit3_T1w.nii
# Batch 0 processed and saved.
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-034/ses-visit2/anat/sub-034_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-034/ses-visit5/anat/sub-034_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-035/ses-visit5/anat/sub-035_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-039/ses-visit2/anat/sub-039_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-040/ses-visit3/anat/sub-040_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit1/anat/sub-042_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit2/anat/sub-042_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit4/anat/sub-042_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-042/ses-visit5/anat/sub-042_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-043/ses-visit5/anat/sub-043_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-044/ses-visit1/anat/sub-044_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-044/ses-visit2/anat/sub-044_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-045/ses-visit5/anat/sub-045_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-046/ses-visit5/anat/sub-046_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-047/ses-visit2/anat/sub-047_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-047/ses-visit5/anat/sub-047_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-048/ses-visit5/anat/sub-048_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-049/ses-visit3/anat/sub-049_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-050/ses-visit3/anat/sub-050_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-050/ses-visit5/anat/sub-050_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-051/ses-visit5/anat/sub-051_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-052/ses-visit4/anat/sub-052_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-052/ses-visit5/anat/sub-052_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-054/ses-visit2/anat/sub-054_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-054/ses-visit5/anat/sub-054_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-055/ses-visit5/anat/sub-055_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-056/ses-visit1/anat/sub-056_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-056/ses-visit4/anat/sub-056_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-056/ses-visit5/anat/sub-056_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-057/ses-visit2/anat/sub-057_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-059/ses-visit1/anat/sub-059_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-059/ses-visit3/anat/sub-059_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-061/ses-visit1/anat/sub-061_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-061/ses-visit4/anat/sub-061_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-063/ses-visit3/anat/sub-063_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-063/ses-visit4/anat/sub-063_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-063/ses-visit5/anat/sub-063_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-064/ses-visit5/anat/sub-064_ses-visit5_T1w.nii
# Batch 1 processed and saved.
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-065/ses-visit5/anat/sub-065_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-066/ses-visit5/anat/sub-066_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-068/ses-visit4/anat/sub-068_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-070/ses-visit3/anat/sub-070_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-070/ses-visit5/anat/sub-070_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-071/ses-visit5/anat/sub-071_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-072/ses-visit4/anat/sub-072_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-072/ses-visit5/anat/sub-072_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-073/ses-visit3/anat/sub-073_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-073/ses-visit5/anat/sub-073_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-074/ses-visit5/anat/sub-074_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-075/ses-visit1/anat/sub-075_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-075/ses-visit5/anat/sub-075_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-076/ses-visit5/anat/sub-076_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-077/ses-visit5/anat/sub-077_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-078/ses-visit2/anat/sub-078_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-078/ses-visit4/anat/sub-078_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-078/ses-visit5/anat/sub-078_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-079/ses-visit5/anat/sub-079_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-080/ses-visit5/anat/sub-080_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-081/ses-visit5/anat/sub-081_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-082/ses-visit5/anat/sub-082_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-083/ses-visit5/anat/sub-083_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-084/ses-visit5/anat/sub-084_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-085/ses-visit1/anat/sub-085_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-085/ses-visit5/anat/sub-085_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-086/ses-visit2/anat/sub-086_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-086/ses-visit5/anat/sub-086_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-087/ses-visit5/anat/sub-087_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-088/ses-visit5/anat/sub-088_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-089/ses-visit5/anat/sub-089_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-090/ses-visit5/anat/sub-090_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-091/ses-visit5/anat/sub-091_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit1/anat/sub-092_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit2/anat/sub-092_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit3/anat/sub-092_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit4/anat/sub-092_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-092/ses-visit5/anat/sub-092_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit1/anat/sub-093_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit2/anat/sub-093_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit3/anat/sub-093_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit4/anat/sub-093_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-093/ses-visit5/anat/sub-093_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit1/anat/sub-094_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit2/anat/sub-094_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit3/anat/sub-094_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit4/anat/sub-094_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-094/ses-visit5/anat/sub-094_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit1/anat/sub-095_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit2/anat/sub-095_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit3/anat/sub-095_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit4/anat/sub-095_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-095/ses-visit5/anat/sub-095_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-096/ses-visit4/anat/sub-096_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-096/ses-visit5/anat/sub-096_ses-visit5_T1w.nii
# Batch 2 processed and saved.
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-097/ses-visit3/anat/sub-097_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-097/ses-visit5/anat/sub-097_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-098/ses-visit5/anat/sub-098_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-visit2/anat/sub-099_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-visit3/anat/sub-099_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-visit4/anat/sub-099_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-099/ses-visit5/anat/sub-099_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-100/ses-visit5/anat/sub-100_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-101/ses-visit5/anat/sub-101_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-102/ses-visit5/anat/sub-102_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-103/ses-visit5/anat/sub-103_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-visit2/anat/sub-104_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-visit3/anat/sub-104_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-visit4/anat/sub-104_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-104/ses-visit5/anat/sub-104_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-105/ses-visit5/anat/sub-105_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-106/ses-visit5/anat/sub-106_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-107/ses-visit5/anat/sub-107_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-108/ses-visit5/anat/sub-108_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-109/ses-visit5/anat/sub-109_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-110/ses-visit3/anat/sub-110_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-110/ses-visit4/anat/sub-110_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-110/ses-visit5/anat/sub-110_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-111/ses-visit5/anat/sub-111_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-112/ses-visit5/anat/sub-112_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-113/ses-visit3/anat/sub-113_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-113/ses-visit5/anat/sub-113_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-114/ses-visit5/anat/sub-114_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-115/ses-visit2/anat/sub-115_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-115/ses-visit5/anat/sub-115_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-116/ses-visit5/anat/sub-116_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-117/ses-visit4/anat/sub-117_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-117/ses-visit5/anat/sub-117_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-118/ses-visit5/anat/sub-118_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-119/ses-visit5/anat/sub-119_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-120/ses-visit5/anat/sub-120_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-121/ses-visit4/anat/sub-121_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-121/ses-visit5/anat/sub-121_ses-visit5_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit1/anat/sub-122_ses-visit1_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit2/anat/sub-122_ses-visit2_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit3/anat/sub-122_ses-visit3_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit4/anat/sub-122_ses-visit4_T1w.nii
# Warning: MRI file not found at /content/drive/My Drive/ChronicAI/dataset/sub-122/ses-visit5/anat/sub-122_ses-visit5_T1w.nii
# Batch 3 processed and saved.
# All batches preprocessed and saved.
